# %% [markdown]
# # Filtering Unneeded Openings
#
# ## Purpose
# - To understand which openings in the DB may not be helpful for processing.
#
# ## Possible Filters
# - Very large or small win rates - likely just a bad opening for one side, no need to recommend it
# - Extremely rare openings - not enough data to give recommendations

# %%
# Configuration and setup
import pandas as pd
from pathlib import Path
from utils.database.db_utils import get_db_connection

# Define the path to the DuckDB database file
project_root = Path.cwd().parent if "notebooks" in str(Path.cwd()) else Path.cwd()
db_path = project_root / "data" / "processed" / "chess_games.db"

# Set pandas display options for better readability
pd.set_option('display.float_format', '{:,.2f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

print(f"Database path: {db_path}")
print(f"Database exists: {db_path.exists()}")

# Configuration: adjust these numbers to control how many results to show
TOP_N_LEAST_PLAYED_BY_GAMES = 100      # Show N least played openings by total games
TOP_N_LEAST_PLAYED_BY_PLAYERS = 200    # Show N least played openings by unique players  
TOP_N_HIGHEST_SCORING = 15             # Show N highest scoring openings (best win rates)
TOP_N_LOWEST_SCORING = 15              # Show N lowest scoring openings (worst win rates)

print(f"\nAnalysis Configuration:")
print(f"- Least played by games: {TOP_N_LEAST_PLAYED_BY_GAMES}")
print(f"- Least played by players: {TOP_N_LEAST_PLAYED_BY_PLAYERS}")
print(f"- Highest scoring openings: {TOP_N_HIGHEST_SCORING}")
print(f"- Lowest scoring openings: {TOP_N_LOWEST_SCORING}")
# Out:
# Database path: /Users/a/Documents/personalprojects/chess-opening-recommender/data/processed/chess_games.db
# Database exists: True
#
# Analysis Configuration:
# - Least played by games: 100
# - Least played by players: 200
# - Highest scoring openings: 15
# - Lowest scoring openings: 15

# %% [markdown]
# ## 1. Database Overview
#
# First, let's get a high-level overview of our database to understand the scale of data we're working with.

# %%
# Database overview - basic counts
if db_path.exists():
    with get_db_connection(db_path) as con:
        print("=== DATABASE OVERVIEW ===")
        
        # Count total records in each table
        player_count = con.execute('SELECT COUNT(*) FROM player').fetchone()[0]
        opening_count = con.execute('SELECT COUNT(*) FROM opening').fetchone()[0]
        
        print(f"Total Players: {player_count:,}")
        print(f"Total Openings: {opening_count:,}")
        
        # Count total games across all partitions
        total_games = con.execute("""
            SELECT SUM(num_wins + num_draws + num_losses) as total_games
            FROM player_opening_stats
        """).fetchone()[0]
        
        total_stats_records = con.execute('SELECT COUNT(*) FROM player_opening_stats').fetchone()[0]
        
        print(f"Total Games: {total_games:,}")
        print(f"Total Player-Opening-Color Records: {total_stats_records:,}")
        print(f"Average Games per Record: {total_games/total_stats_records:.1f}")
        
        # Show partition distribution
        print("\n--- Partition Distribution ---")
        partitions = ['A', 'B', 'C', 'D', 'E', 'other']
        partition_data = []
        
        for partition in partitions:
            count = con.execute(f'SELECT COUNT(*) FROM player_opening_stats_{partition}').fetchone()[0]
            partition_data.append({'Partition': partition, 'Records': count})
            
        partition_df = pd.DataFrame(partition_data)
        partition_df['Percentage'] = (partition_df['Records'] / partition_df['Records'].sum() * 100).round(2)
        partition_df['Records'] = partition_df['Records'].apply('{:,}'.format)
        partition_df['Percentage'] = partition_df['Percentage'].apply('{:.2f}%'.format)
        
        print(partition_df.to_string(index=False))
else:
    print(f"Database file not found at {db_path}")
# Out:
# === DATABASE OVERVIEW ===
# Total Players: 50,000
# Total Openings: 3,593
# Total Games: 568,894,735
# Total Player-Opening-Color Records: 28,229,204
# Average Games per Record: 20.2
#
# --- Partition Distribution ---
# Partition   Records Percentage
#         A 6,721,561     23.81%
#         B 7,292,844     25.83%
#         C 9,221,077     32.67%
#         D 3,952,764     14.00%
#         E 1,040,958      3.69%
#     other         0      0.00%

# %% [markdown]
# ## 2. Least Played Openings by Total Games
#
# These are openings that have very few total games played across all players. They might be too rare to provide meaningful recommendations.

# %%
# Least played openings by total number of games
if db_path.exists():
    with get_db_connection(db_path) as con:
        print(f"=== TOP {TOP_N_LEAST_PLAYED_BY_GAMES} LEAST PLAYED OPENINGS BY TOTAL GAMES ===")
        
        least_played_by_games = con.execute(f"""
            SELECT 
                o.eco,
                o.name,
                SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games,
                COUNT(DISTINCT pos.player_id) as unique_players,
                COUNT(DISTINCT CASE WHEN pos.color = 'w' THEN pos.player_id END) as white_players,
                COUNT(DISTINCT CASE WHEN pos.color = 'b' THEN pos.player_id END) as black_players,
                -- White's performance when playing this opening
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) as white_wins,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_draws ELSE 0 END) as white_draws,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_losses ELSE 0 END) as white_losses,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as white_games,
                -- Black's performance when playing this opening  
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) as black_wins,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_draws ELSE 0 END) as black_draws,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_losses ELSE 0 END) as black_losses,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as black_games,
                -- Win percentages by color
                ROUND(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_win_pct,
                ROUND(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_win_pct
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            GROUP BY o.id, o.eco, o.name
            ORDER BY total_games ASC
            LIMIT {TOP_N_LEAST_PLAYED_BY_GAMES}
        """).fetchdf()
        
        # Format the display
        display_df = least_played_by_games.copy()
        display_df['total_games'] = display_df['total_games'].apply('{:,}'.format)
        display_df['unique_players'] = display_df['unique_players'].apply('{:,}'.format)
        display_df['white_players'] = display_df['white_players'].apply('{:,}'.format)
        display_df['black_players'] = display_df['black_players'].apply('{:,}'.format)
        display_df['white_games'] = display_df['white_games'].apply('{:,}'.format)
        display_df['black_games'] = display_df['black_games'].apply('{:,}'.format)
        
        # Rename columns for better display
        display_df.columns = ['ECO', 'Opening Name', 'Total Games', 'Unique Players', 
                             'White Players', 'Black Players', 'White Wins', 'White Draws', 'White Losses', 'White Games',
                             'Black Wins', 'Black Draws', 'Black Losses', 'Black Games', 'White Win %', 'Black Win %']
        
        print(display_df.to_string(index=False))
        
        # Summary stats
        total_games_in_results = least_played_by_games['total_games'].sum()
        avg_games_per_opening = least_played_by_games['total_games'].mean()
        median_games_per_opening = least_played_by_games['total_games'].median()
        
        print(f"\n--- Summary Statistics ---")
        print(f"Total games in these {TOP_N_LEAST_PLAYED_BY_GAMES} openings: {total_games_in_results:,}")
        print(f"Average games per opening: {avg_games_per_opening:.1f}")
        print(f"Median games per opening: {median_games_per_opening:.1f}")
        print(f"Min games: {least_played_by_games['total_games'].min():,}")
        print(f"Max games: {least_played_by_games['total_games'].max():,}")
# Out:
# === TOP 100 LEAST PLAYED OPENINGS BY TOTAL GAMES ===
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#
# C63                                 Ruy Lopez: Schliemann Defense, Kostic Defense        15.0              6             2             4        0.00         0.00          2.00         2.0        9.00         0.00          4.00        13.0         0.00        69.23
# C24                                              Bishop's Opening: Pachman Gambit        16.0             16            11             5        5.00         0.00          6.00        11.0        2.00         1.00          2.00         5.0        45.45        40.00
# A00                            Grob Opening: Zilbermints Gambit, Schiller Defense        16.0             15             4            11        0.00         1.00          4.00         5.0        5.00         0.00          6.00        11.0         0.00        45.45
# C83                                            Ruy Lopez: Open, Breslau Variation        16.0             15             8             7        4.00         0.00          5.00         9.0        3.00         0.00          4.00         7.0        44.44        42.86
# B06                                 Pterodactyl Defense: Sicilian, Quetzalcoatlus        16.0             15             5            10        3.00         0.00          2.00         5.0        2.00         0.00          9.00        11.0        60.00        18.18
#
# --- Summary Statistics ---
# Total games in these 100 openings: 685.0
# Average games per opening: 6.8
# Median games per opening: 6.0
# Min games: 1.0
# Max games: 16.0

# %% [markdown]
# ## 3. Least Played Openings by Number of Players
#
# These openings have been played by very few unique players, which might indicate they're too specialized or obscure for general recommendations.

# %%
# Least played openings by number of unique players
if db_path.exists():
    with get_db_connection(db_path) as con:
        print(f"=== TOP {TOP_N_LEAST_PLAYED_BY_PLAYERS} LEAST PLAYED OPENINGS BY UNIQUE PLAYERS ===")
        
        least_played_by_players = con.execute(f"""
            SELECT 
                o.eco,
                o.name,
                COUNT(DISTINCT pos.player_id) as unique_players,
                SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games,
                COUNT(DISTINCT CASE WHEN pos.color = 'w' THEN pos.player_id END) as white_players,
                COUNT(DISTINCT CASE WHEN pos.color = 'b' THEN pos.player_id END) as black_players,
                ROUND(AVG(pos.num_wins + pos.num_draws + pos.num_losses), 1) as avg_games_per_player,
                -- White's performance when playing this opening
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as white_games,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as black_games,
                -- Win percentages by color
                ROUND(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_win_pct,
                ROUND(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_win_pct
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            GROUP BY o.id, o.eco, o.name
            ORDER BY unique_players ASC, total_games ASC
            LIMIT {TOP_N_LEAST_PLAYED_BY_PLAYERS}
        """).fetchdf()
        
        # Format the display
        display_df = least_played_by_players.copy()
        display_df['unique_players'] = display_df['unique_players'].apply('{:,}'.format)
        display_df['total_games'] = display_df['total_games'].apply('{:,}'.format)
        display_df['white_players'] = display_df['white_players'].apply('{:,}'.format)
        display_df['black_players'] = display_df['black_players'].apply('{:,}'.format)
        display_df['white_games'] = display_df['white_games'].apply('{:,}'.format)
        display_df['black_games'] = display_df['black_games'].apply('{:,}'.format)
        
        # Rename columns for better display  
        display_df.columns = ['ECO', 'Opening Name', 'Unique Players', 'Total Games',
                             'White Players', 'Black Players', 'Avg Games/Player', 'White Games', 'Black Games',
                             'White Win %', 'Black Win %']
        
        print(display_df.to_string(index=False))
        
        # Summary stats
        total_players_in_results = least_played_by_players['unique_players'].sum()
        total_games_in_results = least_played_by_players['total_games'].sum()
        avg_players_per_opening = least_played_by_players['unique_players'].mean()
        median_players_per_opening = least_played_by_players['unique_players'].median()
        
        print(f"\n--- Summary Statistics ---")
        print(f"Total unique players across these {TOP_N_LEAST_PLAYED_BY_PLAYERS} openings: {total_players_in_results:,}")
        print(f"Total games in these openings: {total_games_in_results:,}")
        print(f"Average players per opening: {avg_players_per_opening:.1f}")
        print(f"Median players per opening: {median_players_per_opening:.1f}")
        print(f"Min players: {least_played_by_players['unique_players'].min():,}")
        print(f"Max players: {least_played_by_players['unique_players'].max():,}")
# Out:
# === TOP 200 LEAST PLAYED OPENINGS BY UNIQUE PLAYERS ===
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ECO                                                                       Opening Name Unique Players Total Games White Players Black Players  Avg Games/Player White Games Black Games  White Win %  Black Win %
# C51                              Italian Game: Evans Gambit Declined, Hicken Variation              1         1.0             0             1              1.00         0.0         1.0          NaN         0.00
# C39       King's Gambit Accepted: Kieseritzky Gambit, Brentano Defense, Caro Variation              1         1.0             0             1              1.00         0.0         1.0          NaN       100.00
# C88                                                 Ruy Lopez: Closed, Alekhine Gambit              1         1.0             1             0              1.00         1.0         0.0       100.00          NaN
# D99                            Grünfeld Defense: Russian Variation, Yugoslav Variation              1         1.0             1             0              1.00         1.0         0.0         0.00          NaN
# A00                                                Van Geet Opening: Jendrossek Gambit              1         1.0             1             0              1.00         1.0         0.0         0.00          NaN
# E08                                            Catalan Opening: Closed, Spassky Gambit              1         1.0             0             1              1.00         0.0         1.0          NaN         0.00
# C78                                                    Ruy Lopez: Rabinovich Variation              1         1.0             0             1              1.00         0.0         1.0          NaN       100.00
# B06                                  Pterodactyl Defense: Fianchetto, King Pterodactyl              1         1.0             1             0              1.00         1.0         0.0       100.00          NaN
# C80                                                    Ruy Lopez: Open, Harksen Gambit              1         1.0             0             1              1.00         0.0         1.0          NaN       100.00
# A00                                                    Hungarian Opening: Asten Gambit              1         1.0             1             0              1.00         1.0         0.0         0.00          NaN
# C80                                  Ruy Lopez: Open, Bernstein Variation, Luther Line              1         1.0             0             1              1.00         0.0         1.0          NaN         0.00
# C12                         French Defense: McCutcheon Variation, Bogoljubow Variation              1         1.0             0             1              1.00         0.0         1.0          NaN       100.00
# B74           Sicilian Defense: Dragon Variation, Classical Variation, Bernard Defense              1         3.0             0             1              3.00         0.0         3.0          NaN        66.67
# D80                                 Grünfeld Defense: Lutikov Variation, Murrey Attack              2         2.0             1             1              1.00         1.0         1.0       100.00         0.00
# C39                King's Gambit Accepted: Kieseritzky Gambit, Anderssen-Cordel Gambit              2         2.0             1             1              1.00         1.0         1.0       100.00       100.00
# B65                          Sicilian Defense: Richter-Rauzer Variation, Rauzer Attack              2         2.0             1             1              1.00         1.0         1.0         0.00       100.00
# B06            Modern Defense: Semi-Averbakh Variation, Pterodactyl Variation Declined              2         2.0             2             0              1.00         2.0         0.0         0.00          NaN
# A06                                                Zukertort Opening: Regina-Nu Gambit              2         2.0             1             1              1.00         1.0         1.0         0.00       100.00
# C60             Ruy Lopez: Spanish Countergambit, Harding Countergambit, Fricke Gambit              2         2.0             1             1              1.00         1.0         1.0       100.00         0.00
# C51                                          Italian Game: Evans Gambit, Göring Attack              2         2.0             2             0              1.00         2.0         0.0        50.00          NaN
# C48      Four Knights Game: Spanish Variation, Rubinstein Variation, Maróczy Variation              2         2.0             1             1              1.00         1.0         1.0         0.00       100.00
# C49                                            Four Knights Game: Alatortsev Variation              2         2.0             2             0              1.00         2.0         0.0       100.00          NaN
# C33                              King's Gambit Accepted: Bishop's Gambit, Grimm Attack              2         2.0             1             1              1.00         1.0         1.0         0.00         0.00
# C79                        Ruy Lopez: Steinitz Defense Deferred, Boleslavsky Variation              2         2.0             0             2              1.00         0.0         2.0          NaN       100.00
# C51                              Italian Game: Evans Gambit Declined, Pavlov Variation              2         2.0             0             2              1.00         0.0         2.0          NaN        50.00
# A95                                      Dutch Defense: Stonewall, Chekhover Variation              2         2.0             1             1              1.00         1.0         1.0       100.00         0.00
# C33                          King's Gambit Accepted: Bishop's Gambit, McDonnell Attack              2         4.0             1             1              2.00         2.0         2.0        50.00         0.00
# C41                          Philidor Defense: Lopez Countergambit, Jaenisch Variation              2         4.0             1             1              2.00         1.0         3.0       100.00         0.00
# A47                                                   Indian Defense: Schnepper Gambit              3         3.0             2             1              1.00         2.0         1.0        50.00         0.00
# D12                                    Slav Defense: Quiet Variation, Landau Variation              3         3.0             1             2              1.00         1.0         2.0         0.00       100.00
# C00                                                    French Defense: Hoffmann Gambit              3         3.0             1             2              1.00         1.0         2.0         0.00       100.00
# C20                              King's Pawn Game: Wayward Queen Attack, Mellon Gambit              3         3.0             1             2              1.00         1.0         2.0         0.00        50.00
# C67                                          Ruy Lopez: Berlin Defense, Winawer Attack              3         3.0             1             2              1.00         1.0         2.0         0.00        50.00
# C11                        French Defense: Steinitz Variation, Brodsky-Jones Variation              3         3.0             1             2              1.00         1.0         2.0         0.00         0.00
# C45                                                   Scotch Game: Rosenthal Variation              3         4.0             0             3              1.30         0.0         4.0          NaN        25.00
# E87                        King's Indian Defense: Sämisch Variation, Bronstein Defense              3         4.0             1             2              1.30         1.0         3.0         0.00        66.67
# C48                                            Four Knights Game: Bardeleben Variation              3         5.0             3             0              1.70         5.0         0.0        80.00          NaN
# C23                                                Bishop's Opening: Four Pawns Gambit              3         7.0             1             3              1.80         2.0         5.0         0.00        40.00
# C67                                     Ruy Lopez: Berlin Defense, Zukertort Variation              4         4.0             1             3              1.00         1.0         3.0       100.00        33.33
# C45                                             Scotch Game: Paulsen, Gunsberg Defense              4         4.0             3             1              1.00         3.0         1.0        33.33       100.00
# C52                                         Italian Game: Evans Gambit, Johner Defense              4         4.0             3             1              1.00         3.0         1.0        66.67         0.00
# C48                     Four Knights Game: Rubinstein Countergambit, Maróczy Variation              4         4.0             1             3              1.00         1.0         3.0       100.00         0.00
# B51                                     Sicilian Defense: Canal Attack, Dorfman Gambit              4         4.0             2             2              1.00         2.0         2.0        50.00        50.00
# A00                          Van Geet Opening: Pfeiffer Gambit, Sleipnir Countergambit              4         4.0             3             1              1.00         3.0         1.0        33.33       100.00
# C37                          King's Gambit Accepted: Double Muzio Gambit, Young Gambit              4         4.0             3             1              1.00         3.0         1.0        66.67         0.00
# C72                                             Ruy Lopez: Closed, Kecskemet Variation              4         4.0             2             2              1.00         2.0         2.0        50.00        50.00
# A95                            Dutch Defense: Stonewall Variation, Chekhover Variation              4         4.0             3             1              1.00         3.0         1.0        66.67         0.00
# D22                    Queen's Gambit Accepted: Alekhine Defense, Alatortsev Variation              4         4.0             3             1              1.00         3.0         1.0        66.67       100.00
# C43                                        Petrov's Defense: Modern Attack, Tal Gambit              4         6.0             1             3              1.50         3.0         3.0        66.67        66.67
# C97                                       Ruy Lopez: Closed, Chigorin, Yugoslav System              5         5.0             5             0              1.00         5.0         0.0        40.00          NaN
# C20                                  King's Pawn Game: MacLeod Attack, Norwalde Gambit              5         5.0             2             3              1.00         2.0         3.0        50.00        66.67
# C39                            King's Gambit Accepted: Kieseritzky Gambit, Rice Gambit              5         6.0             3             2              1.20         4.0         2.0        50.00        50.00
# C80                                                     Ruy Lopez: Open, Friess Attack              5         6.0             0             5              1.20         0.0         6.0          NaN        50.00
# D45          Semi-Slav Defense: Stoltz Variation, Center Variation, Mikhalchishin Line              5         6.0             4             1              1.20         5.0         1.0        40.00         0.00
# A00                                            Grob Opening: Grob Gambit, Keres Gambit              5         6.0             2             3              1.20         3.0         3.0        66.67        66.67
# A43                  Benoni Defense: Zilbermints-Benoni Gambit, Tamarkin Countergambit              5         7.0             1             4              1.40         1.0         6.0         0.00        16.67
# C39                                   King's Gambit Accepted: Kieseritzky, Rice Gambit              6         7.0             2             4              1.20         3.0         4.0        33.33        50.00
# C80                                                Ruy Lopez: Open, Schlechter Defense              6         7.0             3             3              1.20         4.0         3.0        50.00        33.33
# C20                                  King's Pawn Game: Macleod Attack, Norwalde Gambit              6         9.0             3             3              1.50         6.0         3.0        50.00        33.33
# A06                                                  Zukertort Opening: Pachman Gambit              6         9.0             3             3              1.50         6.0         3.0        66.67        66.67
# C33                         King's Gambit Accepted: Bishop's Gambit, Classical Defense              6        12.0             2             4              2.00         2.0        10.0        50.00        50.00
# C43                                            Russian Game: Modern Attack, Tal Gambit              6        14.0             3             3              2.30        11.0         3.0        63.64       100.00
# C63                                      Ruy Lopez: Schliemann Defense, Kostic Defense              6        15.0             2             4              2.50         2.0        13.0         0.00        69.23
# C67                                    Ruy Lopez: Berlin Defense, Trifunovic Variation              7         7.0             3             4              1.00         3.0         4.0        66.67        50.00
# B07                                       Pirc Defense: 150 Attack, Inner Doll Defense              7         7.0             4             3              1.00         4.0         3.0         0.00        66.67
# C12                        French Defense: MacCutcheon Variation, Bogoljubov Variation              7         7.0             1             6              1.00         1.0         6.0         0.00        50.00
# A00                                              Sodium Attack: Chenoboskion Variation              7         9.0             3             4              1.30         5.0         4.0        60.00        50.00
# B74          Sicilian Defense: Dragon Variation, Classical Variation, Stockholm Attack              7        12.0             5             2              1.70        10.0         2.0        60.00        50.00
# A00                                    Van't Kruijs Opening: Bouncing Bishop Variation              8         8.0             4             4              1.00         4.0         4.0       100.00        50.00
# C42                               Petrov's Defense: Classical Attack, Krause Variation              8         8.0             4             4              1.00         4.0         4.0        50.00        25.00
# A00                                                Van Geet Opening: Warsteiner Gambit              8         9.0             6             2              1.10         7.0         2.0        57.14        50.00
# D00                   Blackmar-Diemer Gambit: von Popiel Gambit, Zilbermints Variation              8        13.0             2             6              1.60         7.0         6.0        57.14        16.67
# B89                     Sicilian Defense: Sozin Attack, Main Line, Sherbakov Variation              8        14.0             4             4              1.80         4.0        10.0        50.00        40.00
# E77                                            King's Indian Defense: Six Pawns Attack              8        22.0             2             6              2.80        14.0         8.0        50.00        25.00
# B43                 Sicilian Defense: Kan Variation, Wing Attack, Christiansen's Dream              8        26.0             4             4              3.30        20.0         6.0        40.00        50.00
# C39               King's Gambit Accepted: Kieseritzky, Salvio Defense, Cozio Variation              9         9.0             5             4              1.00         5.0         4.0        60.00        50.00
# C54                                       Italian Game: Giuoco Piano, Krause Variation              9         9.0             3             6              1.00         3.0         6.0       100.00        33.33
# C27                                                         Vienna Game: Adams' Gambit              9         9.0             0             9              1.00         0.0         9.0          NaN        66.67
# D17                       Slav Defense: Czech Variation, Krause Attack, Fazekas Gambit              9        10.0             5             4              1.10         5.0         5.0        40.00        20.00
# C00                                 French Defense: Banzai-Leong Gambit, Pinova Gambit              9        10.0             3             6              1.10         4.0         6.0        25.00        33.33
# C37                              King's Gambit Accepted: Lolli Gambit, Young Variation              9        12.0             7             2              1.30        10.0         2.0        90.00        50.00
# D20                            Queen's Gambit Accepted: Old Variation, Korchnoi Gambit              9        12.0             3             6              1.30         5.0         7.0        60.00        42.86
# A09                                                    Réti Opening: Penguin Variation             10        10.0             2             8              1.00         2.0         8.0        50.00        25.00
# C38                                               King's Gambit Accepted: Greco Gambit             10        11.0             2             8              1.10         3.0         8.0        33.33        37.50
# A00                                            Amar Opening: Paris Gambit, Gent Gambit             10        12.0             3             7              1.20         5.0         7.0        40.00        28.57
# C52                  Italian Game: Evans Gambit, Compromised Defense, Potter Variation             11        14.0             5             6              1.30         6.0         8.0        16.67        50.00
# D99                             Grünfeld Defense: Russian Variation, Smyslov Variation             11        18.0             3             8              1.60         5.0        13.0        80.00        30.77
# C12                              French Defense: McCutcheon Variation, Duras Variation             11        19.0             7             4              1.70        13.0         6.0        46.15        33.33
# B27                                              Sicilian Defense: Frederico Variation             11        19.0             4             7              1.70         5.0        14.0        80.00        28.57
# C42                                   Russian Game: Classical Attack, Krause Variation             12        12.0             7             5              1.00         7.0         5.0        28.57        60.00
# C80                                               Ruy Lopez: Open, Zukertort Variation             12        12.0             9             3              1.00         9.0         3.0        33.33        33.33
# C51                                     Italian Game: Evans Gambit, Ulvestad Variation             12        13.0             4             8              1.10         5.0         8.0        20.00        50.00
# C43                              Petrov's Defense: Modern Attack, Bardeleben Variation             12        13.0             5             7              1.10         5.0         8.0        40.00        62.50
# C48                         Four Knights Game: Spanish Variation, Bardeleben Variation             12        14.0             7             5              1.20         8.0         6.0        87.50        66.67
# D00                                          Blackmar-Diemer Gambit: Rook Pawn Defense             12        15.0             7             5              1.30         7.0         8.0        71.43        25.00
# E81                                 King's Indian Defense: Sämisch Variation, with Bg5             13        13.0             9             4              1.00         9.0         4.0        66.67         0.00
# C24                                                   Bishop's Opening: Krejcik Gambit             13        13.0             6             7              1.00         6.0         7.0         0.00        42.86
# C80                                                  Ruy Lopez: Open, Knorre Variation             17        19.0             6            11              1.10         6.0        13.0        50.00        53.85
# A40                                              Colle System: Siroccopteryx Variation             17        21.0            10             7              1.20        10.0        11.0        70.00        63.64
# E87  King's Indian Defense: Sämisch Variation, Orthodox Variation, Bronstein Variation             17        22.0             7            10              1.30        11.0        11.0        54.55        18.18
# C63                                      Ruy Lopez: Schliemann Defense, Kostić Defense             17        32.0            10             7              1.90        12.0        20.0        41.67        35.00
# D49                           Semi-Slav Defense: Meran Variation, Rabinovich Variation             17        36.0             9             8              2.10        11.0        25.0        54.55        36.00
# B00                       Nimzowitsch Defense: El Columpio Defense, El Columpio Gambit             17        37.0            11             6              2.20        12.0        25.0        58.33        52.00
# D57                       Queen's Gambit Declined: Lasker Defense, Bernstein Variation             18        18.0            12             6              1.00        12.0         6.0         0.00        50.00
# C51                          Italian Game: Evans Gambit Declined, Hirschbach Variation             18        23.0             7            11              1.30         7.0        16.0        42.86        62.50
# E36                       Nimzo-Indian Defense: Classical Variation, Romanishin Gambit             18        27.0            10             8              1.50        10.0        17.0        20.00        52.94
# E60                 King's Indian Defense: Fianchetto Variation, Pterodactyl Variation             18        27.0            13             6              1.40        20.0         7.0        30.00        42.86
# A81                                            Dutch Defense: Leningrad, Basman System             18        43.0            12             6              2.40        12.0        31.0        50.00        45.16
# C44                                                    Scotch Game: Hanneken Variation             19        20.0             9            10              1.10        10.0        10.0        50.00        30.00
# A00                                                     Hungarian Opening: Burk Gambit             19        22.0             1            18              1.20         4.0        18.0        50.00        50.00
# C25                                        Vienna Game: Hamppe-Muzio, Dubois Variation             19        23.0            11             8              1.20        11.0        12.0        36.36        66.67
# A20                      English Opening: King's English Variation, Kahiko-Hula Gambit             19        26.0             6            13              1.40        12.0        14.0        58.33        42.86
# D98                               Grünfeld Defense: Russian Variation, Keres Variation             19        42.0             7            12              2.20        26.0        16.0        42.31        50.00
# C49                       Four Knights Game: Spanish Variation, Gunsberg Counterattack             20        24.0            14             6              1.20        18.0         6.0        22.22        33.33
# D47                Semi-Slav Defense: Meran Variation, Wade Variation, Kaidanov Gambit             20        32.0             4            16              1.60        11.0        21.0        36.36        47.62
# C64                                    Ruy Lopez: Classical Defense, Zaitsev Variation             20        60.0             4            16              3.00        33.0        27.0        42.42        40.74
# C20                                                  Portuguese Opening: Miguel Gambit             21        21.0             3            18              1.00         3.0        18.0        33.33        50.00
# A00                                                     Kádas Opening: Steinbok Gambit             21        22.0             7            14              1.00         7.0        15.0        85.71        40.00
# E54         Nimzo-Indian Defense: Normal Variation, Gligoric System, Smyslov Variation             21        25.0            15             6              1.20        15.0        10.0        53.33        60.00
# A42                                          Pterodactyl Defense: Central, Bogolubovia             21        26.0            12             9              1.20        14.0        12.0        35.71        25.00
# E63        King's Indian Defense: Fianchetto Variation, Panno Variation, Blockade Line             21        28.0            10            11              1.30        11.0        17.0        45.45        58.82
# C51                                      Italian Game: Evans Gambit, Paulsen Variation             22        22.0             8            14              1.00         8.0        14.0        50.00        57.14
# C43                                  Russian Game: Modern Attack, Bardeleben Variation             22        25.0            14             8              1.10        16.0         9.0        31.25        44.44
# C25                                    Vienna Game: Paulsen Variation, Mariotti Gambit             22        27.0            13            10              1.20        16.0        11.0        31.25        54.55
# D35                             Queen's Gambit Declined: Exchange, Chameleon Variation             22        27.0            12            10              1.20        16.0        11.0        43.75        36.36
# C42                                  Petrov's Defense: Classical Attack, Marshall Trap             22        42.0            16             6              1.90        18.0        24.0         5.56        87.50
# C56                                Italian Game: Two Knights Defense, Yurdansky Attack             22        46.0             5            17              2.10        16.0        30.0        68.75        16.67
# B51                                      Sicilian Defense: Canal Attack, Moscow Gambit             22        89.0             8            14              4.00        59.0        30.0        47.46        40.00
# C44                                                        Dresden Opening: The Goblin             23        23.0             6            17              1.00         6.0        17.0        33.33        82.35
# A00                                                    Hungarian Opening: Paris Gambit             23        25.0             4            19              1.10         6.0        19.0        83.33        57.89
# C84                                                   Ruy Lopez: Closed, Basque Gambit             23        28.0             9            15              1.20        12.0        16.0        33.33        37.50
# E37                        Nimzo-Indian Defense: Classical Variation, Modern Variation             23        29.0            15             8              1.30        20.0         9.0        50.00        44.44
# C23                            Bishop's Opening: Lewis Countergambit, Walker Variation             24        25.0            14            10              1.00        14.0        11.0        50.00        18.18
# B20                              Sicilian Defense: Kronberger Variation, Nemeth Gambit             24        26.0            12            12              1.10        14.0        12.0        50.00        66.67
# C03        French Defense: Tarrasch Variation, Guimard Defense, Thunderbunny Variation             25        25.0            17             8              1.00        17.0         8.0        64.71        25.00
# A09                                                   Réti Opening: Zilbermints Gambit             25        26.0            15            10              1.00        16.0        10.0        50.00        30.00
# A45                                  Trompowsky Attack: Edge Variation, Hergert Gambit             25        32.0            12            13              1.30        16.0        16.0        62.50        68.75
# C53                                     Italian Game: Giuoco Piano, Eisinger Variation             25        36.0            13            13              1.40        18.0        18.0        50.00        50.00
# E64                 King's Indian Defense: Fianchetto Variation, Pterodactyl Variation             25        39.0            18             7              1.60        26.0        13.0        34.62        53.85
# C25              Vienna Game: Vienna Gambit, Steinitz Gambit, Fraser-Minckwitz Defense             25        45.0            15            10              1.80        29.0        16.0        48.28        50.00
# E00                                                  Catalan Opening: Hungarian Gambit             25        52.0            17             8              2.10        29.0        23.0        48.28        47.83
# B30          Sicilian Defense: Closed, Anti-Sveshnikov Variation, Kharlov-Kramnik Line             25        69.0            12            13              2.80        20.0        49.0        45.00        28.57
# D00                         Blackmar-Diemer Gambit: Bogoljubov Defense, Mad Dog Attack             25        74.0             7            18              3.00        55.0        19.0        61.82        36.84
# A00                                                       Sodium Attack: Durkin Gambit             26        28.0             2            24              1.10         4.0        24.0        25.00        58.33
# C52                                      Italian Game: Evans Gambit, Richardson Attack             26        28.0            13            13              1.10        14.0        14.0        71.43        57.14
# C37                                    King's Gambit Accepted: Middleton Countergambit             26        41.0             9            17              1.60        10.0        31.0        50.00        67.74
# B20                                         Sicilian Defense: Wing Gambit, Nanu Gambit             26        61.0             6            20              2.30        36.0        25.0        50.00        48.00
# C55              Italian Game: Two Knights Defense, Max Lange Attack, Berger Variation             27        37.0            11            17              1.30        14.0        23.0        50.00        52.17
# B10                           Caro-Kann Defense: Spike Variation, Scorpion-Grob Gambit             33        64.0             4            29              1.90        35.0        29.0        48.57        51.72
# C66                               Ruy Lopez: Closed Berlin Defense, Chigorin Variation             33        73.0            21            12              2.20        21.0        52.0        61.90        42.31
#
# --- Summary Statistics ---
# Total unique players across these 200 openings: 2,811
# Total games in these openings: 4,185.0
# Average players per opening: 14.1
# Median players per opening: 13.5
# Min players: 1
# Max players: 33

# %% [markdown]
# ## 4. Highest Scoring Openings by Color (Best Win Rates)
#
# These openings have the highest win rates for White or Black, which might indicate they're unbalanced or too situational to be useful for general recommendations. We analyze each color separately since openings perform very differently depending on which side plays them.

# %%
# Highest scoring openings for White (best win rates for White)
if db_path.exists():
    with get_db_connection(db_path) as con:
        print(f"=== TOP {TOP_N_HIGHEST_SCORING} HIGHEST SCORING OPENINGS FOR WHITE (MIN 50 GAMES AS WHITE) ===")
        
        highest_scoring_white = con.execute(f"""
            SELECT 
                o.eco,
                o.name,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as white_games,
                COUNT(DISTINCT CASE WHEN pos.color = 'w' THEN pos.player_id END) as white_players,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) as white_wins,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_draws ELSE 0 END) as white_draws,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_losses ELSE 0 END) as white_losses,
                ROUND(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_win_pct,
                ROUND(SUM(CASE WHEN pos.color = 'w' THEN pos.num_draws ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_draw_pct,
                -- Score calculation: (wins + 0.5*draws) / total_games * 100
                ROUND((SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) + 0.5 * SUM(CASE WHEN pos.color = 'w' THEN pos.num_draws ELSE 0 END)) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_score_pct
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'w'
            GROUP BY o.id, o.eco, o.name
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50  -- Min games as White
            ORDER BY white_score_pct DESC, white_games DESC
            LIMIT {TOP_N_HIGHEST_SCORING}
        """).fetchdf()
        
        # Format the display
        display_df = highest_scoring_white.copy()
        display_df['white_games'] = display_df['white_games'].apply('{:,}'.format)
        display_df['white_players'] = display_df['white_players'].apply('{:,}'.format)
        display_df['white_wins'] = display_df['white_wins'].apply('{:,}'.format)
        display_df['white_draws'] = display_df['white_draws'].apply('{:,}'.format)
        display_df['white_losses'] = display_df['white_losses'].apply('{:,}'.format)
        
        # Rename columns for better display
        display_df.columns = ['ECO', 'Opening Name', 'White Games', 'White Players', 'White Wins', 'White Draws', 'White Losses',
                             'White Win %', 'White Draw %', 'White Score %']
        
        print(display_df.to_string(index=False))
        
        # Summary stats
        avg_score = highest_scoring_white['white_score_pct'].mean()
        median_score = highest_scoring_white['white_score_pct'].median()
        min_score = highest_scoring_white['white_score_pct'].min()
        max_score = highest_scoring_white['white_score_pct'].max()
        
        print(f"\n--- White Performance Summary ---")
        print(f"Average White score: {avg_score:.2f}%")
        print(f"Median White score: {median_score:.2f}%")
        print(f"White score range: {min_score:.2f}% - {max_score:.2f}%")
        print(f"Note: Score = (Wins + 0.5*Draws) / Total Games * 100")
        
        print(f"\n=== TOP {TOP_N_HIGHEST_SCORING} HIGHEST SCORING OPENINGS FOR BLACK (MIN 50 GAMES AS BLACK) ===")
        
        highest_scoring_black = con.execute(f"""
            SELECT 
                o.eco,
                o.name,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as black_games,
                COUNT(DISTINCT CASE WHEN pos.color = 'b' THEN pos.player_id END) as black_players,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) as black_wins,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_draws ELSE 0 END) as black_draws,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_losses ELSE 0 END) as black_losses,
                ROUND(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_win_pct,
                ROUND(SUM(CASE WHEN pos.color = 'b' THEN pos.num_draws ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_draw_pct,
                -- Score calculation: (wins + 0.5*draws) / total_games * 100
                ROUND((SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) + 0.5 * SUM(CASE WHEN pos.color = 'b' THEN pos.num_draws ELSE 0 END)) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_score_pct
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'b'
            GROUP BY o.id, o.eco, o.name
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50  -- Min games as Black
            ORDER BY black_score_pct DESC, black_games DESC
            LIMIT {TOP_N_HIGHEST_SCORING}
        """).fetchdf()
        
        # Format the display
        display_df = highest_scoring_black.copy()
        display_df['black_games'] = display_df['black_games'].apply('{:,}'.format)
        display_df['black_players'] = display_df['black_players'].apply('{:,}'.format)
        display_df['black_wins'] = display_df['black_wins'].apply('{:,}'.format)
        display_df['black_draws'] = display_df['black_draws'].apply('{:,}'.format)
        display_df['black_losses'] = display_df['black_losses'].apply('{:,}'.format)
        
        # Rename columns for better display
        display_df.columns = ['ECO', 'Opening Name', 'Black Games', 'Black Players', 'Black Wins', 'Black Draws', 'Black Losses',
                             'Black Win %', 'Black Draw %', 'Black Score %']
        
        print(display_df.to_string(index=False))
        
        # Summary stats
        avg_score = highest_scoring_black['black_score_pct'].mean()
        median_score = highest_scoring_black['black_score_pct'].median()
        min_score = highest_scoring_black['black_score_pct'].min()
        max_score = highest_scoring_black['black_score_pct'].max()
        
        print(f"\n--- Black Performance Summary ---")
        print(f"Average Black score: {avg_score:.2f}%")
        print(f"Median Black score: {median_score:.2f}%")
        print(f"Black score range: {min_score:.2f}% - {max_score:.2f}%")
        print(f"Note: Score = (Wins + 0.5*Draws) / Total Games * 100")
# Out:
# === TOP 15 HIGHEST SCORING OPENINGS FOR WHITE (MIN 50 GAMES AS WHITE) ===
# ECO                                                                    Opening Name White Games White Players White Wins White Draws White Losses  White Win %  White Draw %  White Score %
# C44                                                     Scotch Game: Sea-Cadet Mate       182.0           130      182.0         0.0          0.0       100.00          0.00         100.00
# C44                                                     Scotch Game: Sea-cadet Mate        58.0            45       58.0         0.0          0.0       100.00          0.00         100.00
# B12                                 Caro-Kann Defense: Mieses Attack, Landau Gambit       295.0           139      252.0         5.0         38.0        85.42          1.69          86.27
# A06                                Zukertort Opening: Tennison Gambit, Brigg's Trap     4,885.0         1,122    3,832.0        94.0        959.0        78.44          1.92          79.41
# B00                                                                     King's Pawn    34,737.0        13,738   27,052.0       561.0      7,124.0        77.88          1.61          78.68
# B00                                                                King's Pawn Game    66,747.0        20,869   51,696.0     1,056.0     13,995.0        77.45          1.58          78.24
# C57                                Italian Game: Two Knights Defense, Knight Attack    23,396.0         4,702   17,481.0       558.0      5,357.0        74.72          2.39          75.91
# C55                               Italian Game: Giuoco Piano, Rosentreter Variation       854.0           148      627.0        19.0        208.0        73.42          2.22          74.53
# C54                               Italian Game: Giuoco Piano, Rosentreter Variation     1,671.0           203    1,195.0        47.0        429.0        71.51          2.81          72.92
# C54                                    Italian Game: Giuoco Piano, Aitken Variation     4,842.0           663    3,398.0       115.0      1,329.0        70.18          2.38          71.37
# C25                           Vienna Game: Stanley Variation, Meitner-Mieses Gambit    30,193.0           745   21,161.0       612.0      8,420.0        70.09          2.03          71.10
# C29                                     Vienna Game: Vienna Gambit, Wurzburger Trap     1,400.0            91      966.0        37.0        397.0        69.00          2.64          70.32
# D50 Queen's Gambit Declined: Pseudo-Tarrasch Variation, Canal Variation        98.0            16       61.0         7.0         30.0        62.24          7.14          65.82
# C37           King's Gambit Accepted: Salvio Gambit, Viennese Variation     2,684.0           178    1,729.0        69.0        886.0        64.42          2.57          65.70
# D31                Semi-Slav Defense: Marshall Gambit, Tolush Variation        97.0             8       62.0         3.0         32.0        63.92          3.09          65.46
# C39                     King's Gambit Accepted: Allgaier, Horny Defense       751.0           232      479.0        22.0        250.0        63.78          2.93          65.25
#
# --- Black Performance Summary ---
# Average Black score: 73.86%
# Median Black score: 69.97%
# Black score range: 65.25% - 100.00%
# Note: Score = (Wins + 0.5*Draws) / Total Games * 100

# %% [markdown]
# ## 5. Lowest Scoring Openings by Color (Worst Win Rates)
#
# These openings have the lowest win rates for White or Black, which might indicate they're fundamentally weak or poorly suited for general recommendations.

# %%
# Lowest scoring openings for White (worst win rates for White)
if db_path.exists():
    with get_db_connection(db_path) as con:
        print(f"=== TOP {TOP_N_LOWEST_SCORING} LOWEST SCORING OPENINGS FOR WHITE (MIN 50 GAMES AS WHITE) ===")
        
        lowest_scoring_white = con.execute(f"""
            SELECT 
                o.eco,
                o.name,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as white_games,
                COUNT(DISTINCT CASE WHEN pos.color = 'w' THEN pos.player_id END) as white_players,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) as white_wins,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_draws ELSE 0 END) as white_draws,
                SUM(CASE WHEN pos.color = 'w' THEN pos.num_losses ELSE 0 END) as white_losses,
                ROUND(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_win_pct,
                ROUND(SUM(CASE WHEN pos.color = 'w' THEN pos.num_draws ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_draw_pct,
                -- Score calculation: (wins + 0.5*draws) / total_games * 100
                ROUND((SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) + 0.5 * SUM(CASE WHEN pos.color = 'w' THEN pos.num_draws ELSE 0 END)) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as white_score_pct
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'w'
            GROUP BY o.id, o.eco, o.name
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50  -- Min games as White
            ORDER BY white_score_pct ASC, white_games DESC
            LIMIT {TOP_N_LOWEST_SCORING}
        """).fetchdf()
        
        # Format the display
        display_df = lowest_scoring_white.copy()
        display_df['white_games'] = display_df['white_games'].apply('{:,}'.format)
        display_df['white_players'] = display_df['white_players'].apply('{:,}'.format)
        display_df['white_wins'] = display_df['white_wins'].apply('{:,}'.format)
        display_df['white_draws'] = display_df['white_draws'].apply('{:,}'.format)
        display_df['white_losses'] = display_df['white_losses'].apply('{:,}'.format)
        
        # Rename columns for better display
        display_df.columns = ['ECO', 'Opening Name', 'White Games', 'White Players', 'White Wins', 'White Draws', 'White Losses',
                             'White Win %', 'White Draw %', 'White Score %']
        
        print(display_df.to_string(index=False))
        
        # Summary stats
        avg_score = lowest_scoring_white['white_score_pct'].mean()
        median_score = lowest_scoring_white['white_score_pct'].median()
        min_score = lowest_scoring_white['white_score_pct'].min()
        max_score = lowest_scoring_white['white_score_pct'].max()
        
        print(f"\n--- White Performance Summary ---")
        print(f"Average White score: {avg_score:.2f}%")
        print(f"Median White score: {median_score:.2f}%")
        print(f"White score range: {min_score:.2f}% - {max_score:.2f}%")
        print(f"Note: Score = (Wins + 0.5*Draws) / Total Games * 100")
        
        print(f"\n=== TOP {TOP_N_LOWEST_SCORING} LOWEST SCORING OPENINGS FOR BLACK (MIN 50 GAMES AS BLACK) ===")
        
        lowest_scoring_black = con.execute(f"""
            SELECT 
                o.eco,
                o.name,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as black_games,
                COUNT(DISTINCT CASE WHEN pos.color = 'b' THEN pos.player_id END) as black_players,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) as black_wins,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_draws ELSE 0 END) as black_draws,
                SUM(CASE WHEN pos.color = 'b' THEN pos.num_losses ELSE 0 END) as black_losses,
                ROUND(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_win_pct,
                ROUND(SUM(CASE WHEN pos.color = 'b' THEN pos.num_draws ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_draw_pct,
                -- Score calculation: (wins + 0.5*draws) / total_games * 100
                ROUND((SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) + 0.5 * SUM(CASE WHEN pos.color = 'b' THEN pos.num_draws ELSE 0 END)) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 2) as black_score_pct
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'b'
            GROUP BY o.id, o.eco, o.name
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50  -- Min games as Black
            ORDER BY black_score_pct ASC, black_games DESC
            LIMIT {TOP_N_LOWEST_SCORING}
        """).fetchdf()
        
        # Format the display
        display_df = lowest_scoring_black.copy()
        display_df['black_games'] = display_df['black_games'].apply('{:,}'.format)
        display_df['black_players'] = display_df['black_players'].apply('{:,}'.format)
        display_df['black_wins'] = display_df['black_wins'].apply('{:,}'.format)
        display_df['black_draws'] = display_df['black_draws'].apply('{:,}'.format)
        display_df['black_losses'] = display_df['black_losses'].apply('{:,}'.format)
        
        # Rename columns for better display
        display_df.columns = ['ECO', 'Opening Name', 'Black Games', 'Black Players', 'Black Wins', 'Black Draws', 'Black Losses',
                             'Black Win %', 'Black Draw %', 'Black Score %']
        
        print(display_df.to_string(index=False))
        
        # Summary stats
        avg_score = lowest_scoring_black['black_score_pct'].mean()
        median_score = lowest_scoring_black['black_score_pct'].median()
        min_score = lowest_scoring_black['black_score_pct'].min()
        max_score = lowest_scoring_black['black_score_pct'].max()
        
        print(f"\n--- Black Performance Summary ---")
        print(f"Average Black score: {avg_score:.2f}%")
        print(f"Median Black score: {median_score:.2f}%")
        print(f"Black score range: {min_score:.2f}% - {max_score:.2f}%")
        print(f"Note: Score = (Wins + 0.5*Draws) / Total Games * 100")
# Out:
# === TOP 15 LOWEST SCORING OPENINGS FOR WHITE (MIN 50 GAMES AS WHITE) ===
# ECO                                              Opening Name White Games White Players White Wins White Draws White Losses  White Win %  White Draw %  White Score %
# C50                                Blackburne Shilling Gambit     3,561.0         2,327        0.0         0.0      3,561.0         0.00          0.00           0.00
# A00                               Barnes Opening: Fool's Mate       196.0           162        0.0         0.0        196.0         0.00          0.00           0.00
# C88                                Ruy Lopez: Noah's Ark Trap       220.0           192       42.0        11.0        167.0        19.09          5.00          21.59
# C44                                              Irish Gambit     2,080.0         1,246      496.0        37.0      1,547.0        23.85          1.78          24.74
# C50         Italian Game: Giuoco Pianissimo, Dubois Variation     4,110.0         2,419      985.0        67.0      3,058.0        23.97          1.63          24.78
# C71                                Ruy Lopez: Noah's Ark Trap     2,439.0         1,318      621.0       126.0      1,692.0        25.46          5.17          28.04
# B13       Caro-Kann Defense: Exchange Variation, Bulla Attack        85.0            51       23.0         3.0         59.0        27.06          3.53          28.82
# C40                         Latvian Gambit: Behting Variation       222.0           198       67.0         3.0        152.0        30.18          1.35          30.86
# C37              King's Gambit Accepted: Silberschmidt Gambit       707.0           467      212.0        17.0        478.0        29.99          2.40          31.19
# C29                           Vienna Game: Vienna Gambit, Wurzburger Trap     1,129.0           618      289.0        26.0        814.0        25.60          2.30          26.75
# C32      King's Gambit Declined: Falkbeer Countergambit, Alapin Variation        93.0            66       26.0         0.0         67.0        27.96          0.00          27.96
# C54                          Italian Game: Giuoco Piano, Aitken Variation     2,950.0         1,556      801.0        74.0      2,075.0        27.15          2.51          28.41
# C25                 Vienna Game: Stanley Variation, Meitner-Mieses Gambit    38,150.0         8,014   10,497.0       753.0     26,900.0        27.52          1.97          28.50
# C25                                      Vienna Game: Hamppe-Muzio Gambit       126.0            72       35.0         2.0         89.0        27.78          1.59          28.57
# C37 King's Gambit Accepted: Muzio Gambit, Kling and Horwitz Counterattack        69.0            49       19.0         3.0         47.0        27.54          4.35          29.71
#
# --- Black Performance Summary ---
# Average Black score: 21.61%
# Median Black score: 25.08%
# Black score range: 0.00% - 29.71%
# Note: Score = (Wins + 0.5*Draws) / Total Games * 100

# %% [markdown]
# ## 6. Distribution Analysis
#
# Let's look at the overall distribution of games and players to understand what thresholds might make sense for filtering.

# %%
# Distribution analysis - understand the spread of data to inform filtering decisions
if db_path.exists():
    with get_db_connection(db_path) as con:
        print("=== OPENING DISTRIBUTION ANALYSIS ===")
        
        # Get distribution statistics for all openings
        distribution_stats = con.execute("""
            SELECT 
                COUNT(*) as total_openings,
                MIN(total_games) as min_games,
                MAX(total_games) as max_games,
                ROUND(AVG(total_games), 1) as avg_games,
                ROUND(MEDIAN(total_games), 1) as median_games,
                ROUND(STDDEV(total_games), 1) as stddev_games,
                MIN(unique_players) as min_players,
                MAX(unique_players) as max_players,
                ROUND(AVG(unique_players), 1) as avg_players,
                ROUND(MEDIAN(unique_players), 1) as median_players,
                ROUND(STDDEV(unique_players), 1) as stddev_players
            FROM (
                SELECT 
                    o.id,
                    SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games,
                    COUNT(DISTINCT pos.player_id) as unique_players
                FROM opening o
                JOIN player_opening_stats pos ON o.id = pos.opening_id
                GROUP BY o.id
            ) stats
        """).fetchone()
        
        print("--- All Openings Statistics ---")
        print(f"Total Openings: {distribution_stats[0]:,}")
        print(f"Games per Opening - Min: {distribution_stats[1]:,}, Max: {distribution_stats[2]:,}, Avg: {distribution_stats[3]:,}, Median: {distribution_stats[4]:,}")
        print(f"Players per Opening - Min: {distribution_stats[5]:,}, Max: {distribution_stats[6]:,}, Avg: {distribution_stats[7]:,}, Median: {distribution_stats[8]:,}")
        
        # Percentile analysis for games
        print("\n--- Games per Opening Percentiles ---")
        games_percentiles = con.execute("""
            SELECT 
                ROUND(PERCENTILE_CONT(0.1) WITHIN GROUP (ORDER BY total_games), 1) as p10,
                ROUND(PERCENTILE_CONT(0.25) WITHIN GROUP (ORDER BY total_games), 1) as p25,
                ROUND(PERCENTILE_CONT(0.5) WITHIN GROUP (ORDER BY total_games), 1) as p50,
                ROUND(PERCENTILE_CONT(0.75) WITHIN GROUP (ORDER BY total_games), 1) as p75,
                ROUND(PERCENTILE_CONT(0.9) WITHIN GROUP (ORDER BY total_games), 1) as p90,
                ROUND(PERCENTILE_CONT(0.95) WITHIN GROUP (ORDER BY total_games), 1) as p95,
                ROUND(PERCENTILE_CONT(0.99) WITHIN GROUP (ORDER BY total_games), 1) as p99
            FROM (
                SELECT SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games
                FROM opening o
                JOIN player_opening_stats pos ON o.id = pos.opening_id
                GROUP BY o.id
            ) stats
        """).fetchone()
        
        percentile_labels = ['10th', '25th', '50th (Median)', '75th', '90th', '95th', '99th']
        for i, label in enumerate(percentile_labels):
            print(f"{label}: {games_percentiles[i]:,} games")
        
        # Percentile analysis for players
        print("\n--- Players per Opening Percentiles ---")
        players_percentiles = con.execute("""
            SELECT 
                ROUND(PERCENTILE_CONT(0.1) WITHIN GROUP (ORDER BY unique_players), 1) as p10,
                ROUND(PERCENTILE_CONT(0.25) WITHIN GROUP (ORDER BY unique_players), 1) as p25,
                ROUND(PERCENTILE_CONT(0.5) WITHIN GROUP (ORDER BY unique_players), 1) as p50,
                ROUND(PERCENTILE_CONT(0.75) WITHIN GROUP (ORDER BY unique_players), 1) as p75,
                ROUND(PERCENTILE_CONT(0.9) WITHIN GROUP (ORDER BY unique_players), 1) as p90,
                ROUND(PERCENTILE_CONT(0.95) WITHIN GROUP (ORDER BY unique_players), 1) as p95,
                ROUND(PERCENTILE_CONT(0.99) WITHIN GROUP (ORDER BY unique_players), 1) as p99
            FROM (
                SELECT COUNT(DISTINCT pos.player_id) as unique_players
                FROM opening o
                JOIN player_opening_stats pos ON o.id = pos.opening_id
                GROUP BY o.id
            ) stats
        """).fetchone()
        
        for i, label in enumerate(percentile_labels):
            print(f"{label}: {players_percentiles[i]:,} players")
        
        # Count openings by game thresholds
        print("\n--- Openings by Game Count Thresholds ---")
        game_thresholds = [1, 10, 50, 100, 500, 1000, 5000, 10000]
        for threshold in game_thresholds:
            count = con.execute(f"""
                SELECT COUNT(*)
                FROM (
                    SELECT SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games
                    FROM opening o
                    JOIN player_opening_stats pos ON o.id = pos.opening_id
                    GROUP BY o.id
                    HAVING total_games < {threshold}
                ) stats
            """).fetchone()[0]
            percentage = (count / distribution_stats[0]) * 100
            print(f"Openings with < {threshold:,} games: {count:,} ({percentage:.1f}%)")
        
        # Count openings by player thresholds
        print("\n--- Openings by Player Count Thresholds ---")
        player_thresholds = [1, 5, 10, 25, 50, 100, 500, 1000]
        for threshold in player_thresholds:
            count = con.execute(f"""
                SELECT COUNT(*)
                FROM (
                    SELECT COUNT(DISTINCT pos.player_id) as unique_players
                    FROM opening o
                    JOIN player_opening_stats pos ON o.id = pos.opening_id
                    GROUP BY o.id
                    HAVING unique_players < {threshold}
                ) stats
            """).fetchone()[0]
            percentage = (count / distribution_stats[0]) * 100
            print(f"Openings with < {threshold:,} players: {count:,} ({percentage:.1f}%)")
# Out:
# === OPENING DISTRIBUTION ANALYSIS ===
# --- All Openings Statistics ---
# Total Openings: 3,593
# Games per Opening - Min: 1, Max: 11,806,290, Avg: 158,334.2, Median: 10,064.0
# Players per Opening - Min: 640,532.8, Max: 1, Avg: 49,996, Median: 6,749.1
#
# --- Games per Opening Percentiles ---
# 10th: 157.0 games
# 25th: 1,270.0 games
# 50th (Median): 10,064.0 games
# 75th: 62,039.0 games
# 90th: 302,352.6 games
# 95th: 686,576.4 games
# 99th: 2,882,848.7 games
#
# --- Players per Opening Percentiles ---
# --- All Openings Statistics ---
# Total Openings: 3,593
# Games per Opening - Min: 1, Max: 11,806,290, Avg: 158,334.2, Median: 10,064.0
# Players per Opening - Min: 640,532.8, Max: 1, Avg: 49,996, Median: 6,749.1
#
# --- Games per Opening Percentiles ---
# 10th: 157.0 games
# 25th: 1,270.0 games
# 50th (Median): 10,064.0 games
# 75th: 62,039.0 games
# 90th: 302,352.6 games
# 95th: 686,576.4 games
# 99th: 2,882,848.7 games
#
# --- Players per Opening Percentiles ---
# 10th: 95.2 players
# 25th: 497.0 players
# 50th (Median): 2,636.0 players
# 75th: 9,309.0 players
# 90th: 20,708.8 players
# 95th: 28,192.8 players
# 99th: 39,333.1 players
#
# --- Openings by Game Count Thresholds ---
# Openings with < 1 games: 0 (0.0%)
# Openings with < 10 games: 70 (1.9%)
# 10th: 95.2 players
# 25th: 497.0 players
# 50th (Median): 2,636.0 players
# 75th: 9,309.0 players
# 90th: 20,708.8 players
# 95th: 28,192.8 players
# 99th: 39,333.1 players
#
# --- Openings by Game Count Thresholds ---
# Openings with < 1 games: 0 (0.0%)
# Openings with < 10 games: 70 (1.9%)
# Openings with < 50 games: 203 (5.6%)
# Openings with < 100 games: 285 (7.9%)
# Openings with < 500 games: 622 (17.3%)
# Openings with < 1,000 games: 820 (22.8%)
# Openings with < 50 games: 203 (5.6%)
# Openings with < 100 games: 285 (7.9%)
# Openings with < 500 games: 622 (17.3%)
# Openings with < 1,000 games: 820 (22.8%)
# Openings with < 5,000 games: 1,454 (40.5%)
# Openings with < 10,000 games: 1,794 (49.9%)
#
# --- Openings by Player Count Thresholds ---
# Openings with < 5,000 games: 1,454 (40.5%)
# Openings with < 10,000 games: 1,794 (49.9%)
#
# --- Openings by Player Count Thresholds ---
# Openings with < 1 players: 0 (0.0%)
# Openings with < 1 players: 0 (0.0%)
# Openings with < 5 players: 49 (1.4%)
# Openings with < 5 players: 49 (1.4%)
# Openings with < 10 players: 82 (2.3%)
# Openings with < 10 players: 82 (2.3%)
# Openings with < 25 players: 159 (4.4%)
# Openings with < 25 players: 159 (4.4%)
# Openings with < 50 players: 250 (7.0%)
# Openings with < 50 players: 250 (7.0%)
# Openings with < 100 players: 373 (10.4%)
# Openings with < 100 players: 373 (10.4%)
# Openings with < 500 players: 900 (25.0%)
# Openings with < 500 players: 900 (25.0%)
# Openings with < 1,000 players: 1,181 (32.9%)
# Openings with < 1,000 players: 1,181 (32.9%)

# %% [markdown]
# ## 7. Recommendations for Filtering
#
# Based on the analysis above, here are some recommendations for filtering unneeded openings from the database.

# %%
# Generate filtering recommendations based on the analysis
if db_path.exists():
    with get_db_connection(db_path) as con:
        print("=== FILTERING RECOMMENDATIONS ===")
        
        # Calculate some threshold recommendations
        total_openings = con.execute('SELECT COUNT(*) FROM opening').fetchone()[0]
        
        # Recommendation 1: Filter by minimum games
        min_games_threshold = 50  # Adjust based on your needs
        openings_below_games_threshold = con.execute(f"""
            SELECT COUNT(*)
            FROM (
                SELECT SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games
                FROM opening o
                JOIN player_opening_stats pos ON o.id = pos.opening_id
                GROUP BY o.id
                HAVING total_games < {min_games_threshold}
            ) stats
        """).fetchone()[0]
        
        games_filter_percentage = (openings_below_games_threshold / total_openings) * 100
        
        print(f"1. MINIMUM GAMES FILTER (< {min_games_threshold} games):")
        print(f"   - Would remove {openings_below_games_threshold:,} openings ({games_filter_percentage:.1f}% of total)")
        print(f"   - Rationale: Too few games to provide reliable recommendations")
        
        # Recommendation 2: Filter by minimum players
        min_players_threshold = 10  # Adjust based on your needs
        openings_below_players_threshold = con.execute(f"""
            SELECT COUNT(*)
            FROM (
                SELECT COUNT(DISTINCT pos.player_id) as unique_players
                FROM opening o
                JOIN player_opening_stats pos ON o.id = pos.opening_id
                GROUP BY o.id
                HAVING unique_players < {min_players_threshold}
            ) stats
        """).fetchone()[0]
        
        players_filter_percentage = (openings_below_players_threshold / total_openings) * 100
        
        print(f"\n2. MINIMUM PLAYERS FILTER (< {min_players_threshold} unique players):")
        print(f"   - Would remove {openings_below_players_threshold:,} openings ({players_filter_percentage:.1f}% of total)")
        print(f"   - Rationale: Too few players to generalize recommendations")
        
        # Recommendation 3: Filter by extreme win rates (by color)
        extreme_win_rate_threshold = 75.0  # Adjust based on your needs
        
        # Count openings with extreme win rates for White
        extreme_white_high = con.execute(f"""
            SELECT COUNT(DISTINCT o.id)
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'w'
            GROUP BY o.id
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50
            AND SUM(pos.num_wins) * 100.0 / NULLIF(SUM(pos.num_wins + pos.num_draws + pos.num_losses), 0) > {extreme_win_rate_threshold}
        """).fetchone()[0]
        
        extreme_white_low = con.execute(f"""
            SELECT COUNT(DISTINCT o.id)
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'w'
            GROUP BY o.id
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50
            AND SUM(pos.num_wins) * 100.0 / NULLIF(SUM(pos.num_wins + pos.num_draws + pos.num_losses), 0) < {100 - extreme_win_rate_threshold}
        """).fetchone()[0]
        
        # Count openings with extreme win rates for Black
        extreme_black_high = con.execute(f"""
            SELECT COUNT(DISTINCT o.id)
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'b'
            GROUP BY o.id
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50
            AND SUM(pos.num_wins) * 100.0 / NULLIF(SUM(pos.num_wins + pos.num_draws + pos.num_losses), 0) > {extreme_win_rate_threshold}
        """).fetchone()[0]
        
        extreme_black_low = con.execute(f"""
            SELECT COUNT(DISTINCT o.id)
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            WHERE pos.color = 'b'
            GROUP BY o.id
            HAVING SUM(pos.num_wins + pos.num_draws + pos.num_losses) >= 50
            AND SUM(pos.num_wins) * 100.0 / NULLIF(SUM(pos.num_wins + pos.num_draws + pos.num_losses), 0) < {100 - extreme_win_rate_threshold}
        """).fetchone()[0]
        
        # Count unique openings with extreme performance in either color
        extreme_either_color = con.execute(f"""
            SELECT COUNT(DISTINCT o.id)
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            GROUP BY o.id
            HAVING 
                (SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) >= 50
                 AND (SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) > {extreme_win_rate_threshold}
                      OR SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                         NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) < {100 - extreme_win_rate_threshold}))
                OR
                (SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) >= 50
                 AND (SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                      NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) > {extreme_win_rate_threshold}
                      OR SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                         NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) < {100 - extreme_win_rate_threshold}))
        """).fetchone()[0]
        
        extreme_filter_percentage = (extreme_either_color / total_openings) * 100
        
        print(f"\n3. EXTREME WIN RATE FILTER BY COLOR (>{extreme_win_rate_threshold}% or <{100-extreme_win_rate_threshold}% win rate, min 50 games per color):")
        print(f"   - Would remove {extreme_either_color:,} openings ({extreme_filter_percentage:.1f}% of total)")
        print(f"     * White extreme high (>{extreme_win_rate_threshold}%): {extreme_white_high:,}")
        print(f"     * White extreme low (<{100-extreme_win_rate_threshold}%): {extreme_white_low:,}")
        print(f"     * Black extreme high (>{extreme_win_rate_threshold}%): {extreme_black_high:,}")
        print(f"     * Black extreme low (<{100-extreme_win_rate_threshold}%): {extreme_black_low:,}")
        print(f"   - Rationale: Likely unbalanced or situational openings for specific colors")
        
        # Combined filter impact
        combined_filter = con.execute(f"""
            SELECT COUNT(DISTINCT o.id)
            FROM opening o
            JOIN player_opening_stats pos ON o.id = pos.opening_id
            GROUP BY o.id
            HAVING 
                SUM(pos.num_wins + pos.num_draws + pos.num_losses) < {min_games_threshold}
                OR COUNT(DISTINCT pos.player_id) < {min_players_threshold}
                OR (SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) >= 50
                    AND (SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                         NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) > {extreme_win_rate_threshold}
                         OR SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                            NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) < {100 - extreme_win_rate_threshold}))
                OR (SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) >= 50
                    AND (SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                         NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) > {extreme_win_rate_threshold}
                         OR SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                            NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0) < {100 - extreme_win_rate_threshold}))
        """).fetchone()[0]
        
        combined_percentage = (combined_filter / total_openings) * 100
        
        print(f"\n4. COMBINED FILTER IMPACT:")
        print(f"   - Would remove {combined_filter:,} openings ({combined_percentage:.1f}% of total)")
        print(f"   - Remaining openings: {total_openings - combined_filter:,} ({100 - combined_percentage:.1f}% of total)")
        
        print(f"\n=== SUGGESTED THRESHOLDS FOR YOUR USE CASE ===")
        print(f"Minimum Games: {min_games_threshold} (adjust based on desired data quality)")
        print(f"Minimum Players: {min_players_threshold} (adjust based on generalization needs)")
        print(f"Win Rate Bounds by Color: {100-extreme_win_rate_threshold}% - {extreme_win_rate_threshold}% (adjust based on balance requirements)")
        print(f"\nNote: You can modify the threshold variables at the top of this cell to experiment with different values.")
# Out:
# === FILTERING RECOMMENDATIONS ===
# 1. MINIMUM GAMES FILTER (< 50 games):
#    - Would remove 203 openings (5.6% of total)
#    - Rationale: Too few games to provide reliable recommendations
#
# 2. MINIMUM PLAYERS FILTER (< 10 unique players):
#    - Would remove 82 openings (2.3% of total)
#    - Rationale: Too few players to generalize recommendations
#
# 2. MINIMUM PLAYERS FILTER (< 10 unique players):
#    - Would remove 82 openings (2.3% of total)
#    - Rationale: Too few players to generalize recommendations
#
# 3. EXTREME WIN RATE FILTER BY COLOR (>75.0% or <25.0% win rate, min 50 games per color):
#    - Would remove 1 openings (0.0% of total)
#      * White extreme high (>75.0%): 1
#      * White extreme low (<25.0%): 1
#      * Black extreme high (>75.0%): 1
#      * Black extreme low (<25.0%): 1
#    - Rationale: Likely unbalanced or situational openings for specific colors
#
# 3. EXTREME WIN RATE FILTER BY COLOR (>75.0% or <25.0% win rate, min 50 games per color):
#    - Would remove 1 openings (0.0% of total)
#      * White extreme high (>75.0%): 1
#      * White extreme low (<25.0%): 1
#      * Black extreme high (>75.0%): 1
#      * Black extreme low (<25.0%): 1
#    - Rationale: Likely unbalanced or situational openings for specific colors
#
# 4. COMBINED FILTER IMPACT:
#    - Would remove 1 openings (0.0% of total)
#    - Remaining openings: 3,592 (100.0% of total)
#
# === SUGGESTED THRESHOLDS FOR YOUR USE CASE ===
# Minimum Games: 50 (adjust based on desired data quality)
# Minimum Players: 10 (adjust based on generalization needs)
# Win Rate Bounds by Color: 25.0% - 75.0% (adjust based on balance requirements)
#
# Note: You can modify the threshold variables at the top of this cell to experiment with different values.
#
# 4. COMBINED FILTER IMPACT:
#    - Would remove 1 openings (0.0% of total)
#    - Remaining openings: 3,592 (100.0% of total)
#
# === SUGGESTED THRESHOLDS FOR YOUR USE CASE ===
# Minimum Games: 50 (adjust based on desired data quality)
# Minimum Players: 10 (adjust based on generalization needs)
# Win Rate Bounds by Color: 25.0% - 75.0% (adjust based on balance requirements)
#
# Note: You can modify the threshold variables at the top of this cell to experiment with different values.

# %% [markdown]
# ## 8. Openings with Same Name but Different ECO Codes
#
# These are openings that share the same name but have different ECO codes. This could indicate opening variations, transpositions, or potential data quality issues worth investigating.

# %%
# Find openings with same name but different ECO codes
if db_path.exists():
    with get_db_connection(db_path) as con:
        print("=== OPENINGS WITH SAME NAME BUT DIFFERENT ECO CODES ===")
        
        # Find opening names that appear with multiple ECO codes
        duplicate_names = con.execute("""
            SELECT 
                name,
                COUNT(DISTINCT eco) as eco_count,
                STRING_AGG(DISTINCT eco, ', ' ORDER BY eco) as eco_codes,
                COUNT(*) as total_records,
                SUM(total_games) as combined_games,
                SUM(unique_players) as combined_players
            FROM (
                SELECT 
                    o.name,
                    o.eco,
                    SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games,
                    COUNT(DISTINCT pos.player_id) as unique_players
                FROM opening o
                JOIN player_opening_stats pos ON o.id = pos.opening_id
                GROUP BY o.id, o.name, o.eco
            ) stats
            GROUP BY name
            HAVING COUNT(DISTINCT eco) > 1
            ORDER BY eco_count DESC, combined_games DESC
        """).fetchdf()
        
        if len(duplicate_names) > 0:
            print(f"Found {len(duplicate_names)} opening names that appear with multiple ECO codes:\n")
            
            # Format the display
            display_df = duplicate_names.copy()
            display_df['total_records'] = display_df['total_records'].apply('{:,}'.format)
            display_df['combined_games'] = display_df['combined_games'].apply('{:,}'.format)
            display_df['combined_players'] = display_df['combined_players'].apply('{:,}'.format)
            
            # Rename columns for better display
            display_df.columns = ['Opening Name', 'ECO Count', 'ECO Codes', 'Records', 'Total Games', 'Total Players']
            
            print(display_df.to_string(index=False))
            
            # Get detailed breakdown for the most complex cases
            print(f"\n=== DETAILED BREAKDOWN FOR TOP 10 MOST COMPLEX CASES ===")
            
            top_complex_names = duplicate_names.head(10)['name'].tolist()
            
            for name in top_complex_names:
                print(f"\n--- '{name}' ---")
                
                detailed_breakdown = con.execute(f"""
                    SELECT 
                        o.eco,
                        o.name,
                        SUM(pos.num_wins + pos.num_draws + pos.num_losses) as total_games,
                        COUNT(DISTINCT pos.player_id) as unique_players,
                        -- White performance
                        SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as white_games,
                        ROUND(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                              NULLIF(SUM(CASE WHEN pos.color = 'w' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 1) as white_win_pct,
                        -- Black performance  
                        SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END) as black_games,
                        ROUND(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins ELSE 0 END) * 100.0 / 
                              NULLIF(SUM(CASE WHEN pos.color = 'b' THEN pos.num_wins + pos.num_draws + pos.num_losses ELSE 0 END), 0), 1) as black_win_pct
                    FROM opening o
                    JOIN player_opening_stats pos ON o.id = pos.opening_id
                    WHERE o.name = ?
                    GROUP BY o.id, o.eco, o.name
                    ORDER BY total_games DESC
                """, [name]).fetchdf()
                
                # Format for display
                breakdown_display = detailed_breakdown.copy()
                breakdown_display['total_games'] = breakdown_display['total_games'].apply('{:,}'.format)
                breakdown_display['unique_players'] = breakdown_display['unique_players'].apply('{:,}'.format)
                breakdown_display['white_games'] = breakdown_display['white_games'].apply('{:,}'.format)
                breakdown_display['black_games'] = breakdown_display['black_games'].apply('{:,}'.format)
                
                # Drop the name column since it's redundant
                breakdown_display = breakdown_display.drop('name', axis=1)
                breakdown_display.columns = ['ECO', 'Total Games', 'Players', 'White Games', 'White Win%', 'Black Games', 'Black Win%']
                
                print(breakdown_display.to_string(index=False))
            
            # Calculate consolidation savings
            print(f"\n=== CONSOLIDATION SAVINGS ANALYSIS ===")
            
            # Get current table sizes for percentage calculations
            total_openings = con.execute('SELECT COUNT(*) FROM opening').fetchone()[0]
            total_stats_records = con.execute('SELECT COUNT(*) FROM player_opening_stats').fetchone()[0]
            
            # Calculate detailed savings for each duplicated name
            consolidation_savings = []
            
            for _, row in duplicate_names.iterrows():
                name = row['name']
                eco_count = row['eco_count']
                
                # Get stats records that would be affected by consolidating this name
                stats_records = con.execute("""
                    SELECT COUNT(*) as records_count
                    FROM opening o
                    JOIN player_opening_stats pos ON o.id = pos.opening_id
                    WHERE o.name = ?
                """, [name]).fetchone()[0]
                
                # Calculate potential reduction in stats records
                # If we consolidate N ECO variants into 1, we could potentially reduce records
                # by combining stats for the same player-color combinations
                unique_player_color_combos = con.execute("""
                    SELECT COUNT(DISTINCT pos.player_id || '_' || pos.color) as unique_combos
                    FROM opening o
                    JOIN player_opening_stats pos ON o.id = pos.opening_id
                    WHERE o.name = ?
                """, [name]).fetchone()[0]
                
                # Theoretical maximum reduction if all variants were perfectly consolidated
                max_records_after_consolidation = unique_player_color_combos
                potential_record_reduction = stats_records - max_records_after_consolidation
                
                consolidation_savings.append({
                    'name': name,
                    'eco_count': eco_count,
                    'current_records': stats_records,
                    'potential_min_records': max_records_after_consolidation,
                    'potential_reduction': potential_record_reduction,
                    'reduction_pct': (potential_record_reduction / stats_records * 100) if stats_records > 0 else 0
                })
            
            # Convert to DataFrame for analysis
            savings_df = pd.DataFrame(consolidation_savings)
            
            # Calculate total potential savings
            total_current_records = savings_df['current_records'].sum()
            total_potential_reduction = savings_df['potential_reduction'].sum()
            total_reduction_pct = (total_potential_reduction / total_current_records * 100) if total_current_records > 0 else 0
            
            # Show top savings opportunities
            top_savings = savings_df.nlargest(10, 'potential_reduction')
            
            print("--- Top 10 Consolidation Opportunities (by potential record reduction) ---")
            display_savings = top_savings.copy()
            display_savings['current_records'] = display_savings['current_records'].apply('{:,}'.format)
            display_savings['potential_min_records'] = display_savings['potential_min_records'].apply('{:,}'.format)
            display_savings['potential_reduction'] = display_savings['potential_reduction'].apply('{:,}'.format)
            display_savings['reduction_pct'] = display_savings['reduction_pct'].apply('{:.1f}%'.format)
            
            display_savings.columns = ['Opening Name', 'ECO Count', 'Current Records', 'Min Records After', 'Potential Reduction', 'Reduction %']
            print(display_savings.to_string(index=False))
            
            # Summary statistics
            total_duplicated_names = len(duplicate_names)
            max_eco_count = duplicate_names['eco_count'].max()
            avg_eco_count = duplicate_names['eco_count'].mean()
            total_affected_games = duplicate_names['combined_games'].sum()
            total_affected_players = duplicate_names['combined_players'].sum()
            
            # Database size impact
            opening_reduction = duplicate_names['total_records'].sum() - total_duplicated_names
            opening_reduction_pct = (opening_reduction / total_openings * 100) if total_openings > 0 else 0
            stats_reduction_pct = (total_potential_reduction / total_stats_records * 100) if total_stats_records > 0 else 0
            
            print(f"\n=== OVERALL CONSOLIDATION IMPACT ===")
            print(f"Opening names with multiple ECO codes: {total_duplicated_names:,}")
            print(f"Maximum ECO codes for single name: {max_eco_count}")
            print(f"Average ECO codes per duplicated name: {avg_eco_count:.1f}")
            print(f"Total games affected by name duplication: {total_affected_games:,}")
            print(f"Total players affected by name duplication: {total_affected_players:,}")
            
            print(f"\n--- Potential Database Size Reductions ---")
            print(f"Opening table:")
            print(f"  Current entries: {total_openings:,}")
            print(f"  Potential reduction: {opening_reduction:,} entries ({opening_reduction_pct:.2f}%)")
            print(f"  After consolidation: {total_openings - opening_reduction:,} entries")
            
            print(f"\nPlayer-Opening-Stats table:")
            print(f"  Current entries: {total_stats_records:,}")
            print(f"  Records for duplicated names: {total_current_records:,}")
            print(f"  Potential reduction: {total_potential_reduction:,} entries ({stats_reduction_pct:.2f}% of total)")
            print(f"  After consolidation: {total_stats_records - total_potential_reduction:,} entries")
            print(f"  Average reduction per duplicated name: {total_reduction_pct:.1f}%")
            
            # Potential issues to investigate
            print(f"\n=== CONSOLIDATION CONSIDERATIONS ===")
            print("1. Benefits of consolidation:")
            print(f"   - Reduce database size by {stats_reduction_pct:.2f}% in player-opening-stats")
            print(f"   - Reduce opening table by {opening_reduction_pct:.2f}%")
            print("   - Simplify opening recommendations")
            print("   - Combine statistics for better sample sizes")
            print("2. Potential challenges:")
            print("   - Loss of ECO classification granularity")
            print("   - May combine genuinely different opening variations")
            print("   - Need to decide which ECO code to keep or create mapping")
            print("3. Names with many ECO codes might indicate:")
            print("   - Opening transpositions (same position via different moves)")
            print("   - Opening variations classified separately")
            print("   - Potential data quality issues or inconsistent naming")
            print("4. Recommended approach:")
            print("   - Review high-impact consolidations manually")
            print("   - Consider keeping ECO variations as metadata")
            print("   - Create hierarchical opening relationships")
            
        else:
            print("No opening names found with multiple ECO codes.")
            print("All opening names have unique ECO code assignments.")
# Out:
# === OPENINGS WITH SAME NAME BUT DIFFERENT ECO CODES ===
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Found 184 opening names that appear with multiple ECO codes:
#
#                                                                     Opening Name  ECO Count                    ECO Codes Records  Total Games Total Players
#                                          Nimzo-Indian Defense: Sämisch Variation          6 E24, E25, E26, E27, E28, E29       6     65,747.0      16,584.0
#                                              Sicilian Defense: Najdorf Variation          5      B90, B94, B95, B96, B98       5    793,261.0      46,243.0
#                               Ruy Lopez: Morphy Defense, Modern Steinitz Defense          5      C71, C72, C73, C74, C75       5    219,068.0      35,338.0
#                                               Dutch Defense: Classical Variation          5      A84, A90, A91, A92, A96       5    164,971.0      22,233.0
#                                                         Sicilian Defense: Closed          4           B23, B24, B25, B26       4  3,088,206.0      48,529.0
#                                        King's Indian Defense: Orthodox Variation          4           E91, E92, E94, E95       4    311,699.0      20,552.0
#                                                          Catalan Opening: Closed          4           E01, E06, E07, E08       4    238,190.0      32,578.0
#                             French Defense: Winawer Variation, Advance Variation          4           C16, C17, C18, C19       4    181,354.0      27,500.0
#                              Sicilian Defense: Dragon Variation, Yugoslav Attack          4           B76, B77, B78, B79       4     93,627.0      12,630.0
#                                                                Ruy Lopez: Closed          4           C84, C88, C90, C92       4     89,053.0      11,391.0
#                         Nimzo-Indian Defense: Classical Variation, Noa Variation          4           E34, E35, E36, E37       4     64,359.0      13,599.0
#                                                                Queen's Pawn Game          3                A40, A41, D00       3 14,485,459.0     121,932.0
#                                                                   Modern Defense          3                A40, A41, B06       3 10,874,216.0      87,838.0
#                                                                Caro-Kann Defense          3                B10, B12, B15       3 10,163,753.0     109,524.0
#                                            Queen's Pawn Game: Chigorin Variation          3                A45, D00, D02       3  4,311,233.0     108,464.0
#                                                                 Sicilian Defense          3                B20, B27, B50       3  3,941,822.0      96,411.0
#                                                          Queen's Gambit Declined          3                D30, D52, D53       3  3,067,358.0      70,312.0
#                                                          Queen's Gambit Accepted          3                D20, D23, D24       3  1,605,178.0      48,706.0
#                                                                Zukertort Opening          3                A04, A05, A06       3  1,015,422.0      64,572.0
#                                           English Opening: Symmetrical Variation          3                A30, A34, A35       3    952,574.0      28,707.0
#                                                       Vienna Game: Vienna Gambit          3                C25, C26, C29       3    700,870.0      56,045.0
#                                   King's Gambit Accepted: King's Knight's Gambit          3                C34, C37, C39       3    579,118.0      36,746.0
#                               Sicilian Defense: Accelerated Dragon, Maróczy Bind          3                B36, B37, B38       3    181,002.0      15,751.0
#                        Sicilian Defense: Taimanov Variation, Bastrikov Variation          3                B47, B48, B49       3    116,743.0      18,002.0
#                          Sicilian Defense: Dragon Variation, Classical Variation          3                B70, B72, B73       3    110,923.0      16,417.0
#                                                    Catalan Opening: Open Defense          3                E02, E03, E04       3     69,441.0      14,242.0
#                          Grünfeld Defense: Exchange Variation, Spassky Variation          3                D87, D88, D89       3     41,092.0       5,089.0
#                                              Ruy Lopez: Closed, Chigorin Defense          3                C96, C97, C98       3     26,937.0       5,134.0
#                                               Dutch Defense: Stonewall Variation          3                A92, A94, A95       3     20,284.0       4,955.0
#                  Sicilian Defense: Richter-Rauzer Variation, Classical Variation          3                B63, B64, B65       3     14,862.0       3,263.0
#                                 Neo-Grünfeld Defense: Delayed Exchange Variation          3                D74, D75, D76       3     14,834.0       4,478.0
#                            Benoni Defense: Classical Variation, Czerniak Defense          3                A76, A78, A79       3      5,244.0       2,074.0
#                                                                     Pirc Defense          2                     B00, B07       2  8,292,505.0      77,692.0
#                                                                   Indian Defense          2                     A45, E00       2  6,252,996.0      38,947.0
#                                           Queen's Pawn Game: Zukertort Variation          2                     D02, D05       2  4,383,370.0      45,072.0
#                                                                      Scotch Game          2                     C44, C45       2  3,981,181.0      66,862.0
#                                                       Benoni Defense: Old Benoni          2                     A43, A44       2  3,595,699.0      45,756.0
#                                                  Queen's Pawn Game: Colle System          2                     D04, D05       2  2,300,478.0      65,330.0
#                                         Nimzo-Larsen Attack: Classical Variation          2                     A01, A06       2  2,117,066.0      69,817.0
#                                             Four Knights Game: Italian Variation          2                     C47, C50       2  2,001,421.0      60,431.0
#                                                           Sicilian Defense: Open          2                     B32, B33       2  1,923,806.0      51,674.0
#                                        English Opening: King's English Variation          2                     A20, A21       2  1,795,704.0      51,935.0
#                                                                    Dutch Defense          2                     A80, A84       2  1,387,512.0      37,684.0
#                                                       Italian Game: Giuoco Piano          2                     C50, C55       2  1,248,645.0      27,831.0
#                                                               Old Indian Defense          2                     A41, A53       2  1,155,820.0      51,601.0
#                                             Sicilian Defense: Taimanov Variation          2                     B44, B46       2  1,130,207.0      47,360.0
#                                                                 Alekhine Defense          2                     B02, B03       2  1,125,596.0      63,529.0
#                                                Pirc Defense: Classical Variation          2                     B07, B08       2  1,102,253.0      35,729.0
#                                         Englund Gambit Declined: Reversed French          2                     A00, A40       2  1,087,598.0      65,537.0
#                                                                      Center Game          2                     C20, C21       2  1,057,776.0      51,758.0
#                                                Italian Game: Classical Variation          2                     C53, C54       2  1,011,071.0      35,775.0
#                                                               St. George Defense          2                     B00, C00       2    998,515.0      51,035.0
#                                                             King's Indian Attack          2                     A05, A07       2    948,210.0      54,688.0
#                                                                 King's Pawn Game          2                     B00, C20       2    942,336.0      62,889.0
#                                                 Slav Defense: Exchange Variation          2                     D10, D13       2    855,340.0      39,315.0
#                                                Italian Game: Two Knights Defense          2                     C55, C58       2    755,097.0      33,532.0
#                                                King's Pawn Game: Maróczy Defense          2                     A41, B07       2    739,420.0      61,167.0
#                             Italian Game: Classical Variation, Giuoco Pianissimo          2                     C53, C54       2    735,513.0      40,113.0
#                                            English Opening: Anglo-Indian Defense          2                     A15, A17       2    673,212.0      25,595.0
#                                                 Indian Defense: Budapest Defense          2                     A51, A52       2    625,811.0      25,714.0
#                                                  Caro-Kann Defense: Panov Attack          2                     B13, B14       2    624,710.0      37,827.0
#                                           Caro-Kann Defense: Classical Variation          2                     B18, B19       2    533,275.0      25,910.0
#                          French Defense: Classical Variation, Steinitz Variation          2                     C11, C14       2    472,009.0      33,128.0
#                                             Four Knights Game: Spanish Variation          2                     C48, C49       2    452,543.0      26,602.0
#                                                     Semi-Slav Defense: Main Line          2                     D45, D46       2    413,071.0      28,272.0
#                                         Queen's Gambit Declined: Harrwitz Attack          2                     D35, D37       2    407,860.0      33,466.0
#                                       Sicilian Defense: Delayed Alapin Variation          2                     B22, B40       2    320,067.0      18,797.0
#                                                                   Benoni Defense          2                     A56, A61       2    304,673.0      16,064.0
#                                         King's Indian Defense: Four Pawns Attack          2                     E76, E77       2    304,448.0      19,300.0
#                                            Sicilian Defense: Classical Variation          2                     B56, B58       2    297,835.0      24,356.0
#                                                             Nimzo-Indian Defense          2                     E20, E50       2    284,641.0      20,250.0
#                                               Sicilian Defense: Dragon Variation          2                     B70, B72       2    280,108.0      24,100.0
#                                             Sicilian Defense: Accelerated Dragon          2                     B32, B54       2    271,279.0      24,725.0
#                                     King's Gambit Accepted: King's Knight Gambit          2                     C34, C37       2    247,613.0      23,119.0
#                                                                     Benko Gambit          2                     A57, A59       2    223,139.0      14,423.0
#                                                        Ruy Lopez: Morphy Defense          2                     C70, C78       2    204,780.0      23,127.0
#                                      Zukertort Opening: Reversed Mexican Defense          2                     A00, A06       2    198,185.0      38,094.0
#                                     Queen's Gambit Accepted: Rosenthal Variation          2                     D02, D21       2    189,630.0      29,048.0
#                                          Tarrasch Defense: Symmetrical Variation          2                     D32, E10       2    189,245.0      23,722.0
#                                               Sicilian Defense: Drazic Variation          2                     B40, C00       2    188,890.0      28,735.0
#                                        Queen's Gambit Accepted: Normal Variation          2                     D21, D25       2    186,655.0      28,235.0
#                                         King's Indian Attack: Sicilian Variation          2                     A07, A08       2    163,208.0      25,388.0
#                                    Blackmar-Diemer Gambit: Netherlands Variation          2                     A80, D00       2    162,428.0      25,176.0
#                                                                     Torre Attack          2                     A46, A48       2    159,894.0      18,155.0
#                                   Queen's Gambit Declined: Semi-Tarrasch Defense          2                     D40, D41       2    142,323.0      21,958.0
#                     English Opening: Symmetrical Variation, Fianchetto Variation          2                     A34, A36       2    135,114.0      19,349.0
#                            Indian Defense: Colle System, King's Indian Variation          2                     A00, A48       2    128,792.0      16,198.0
#                                 Italian Game: Classical Variation, Center Attack          2                     C53, C54       2    123,613.0      18,511.0
#              Queen's Gambit Declined: Semi-Tarrasch Defense, Pillsbury Variation          2                     D40, D41       2    123,431.0      17,414.0
#                             Italian Game: Two Knights Defense, Perreux Variation          2                     C55, C56       2    120,346.0      21,782.0
#                                Italian Game: Two Knights Defense, Open Variation          2                     C55, C56       2    112,696.0      19,669.0
#                                                        Borg Defense: Borg Gambit          2                     A40, B00       2    111,649.0      31,310.0
#                                    Italian Game: Scotch Gambit, Max Lange Attack          2                     C55, C56       2    102,140.0      14,158.0
#                              Italian Game: Two Knights Defense, Max Lange Attack          2                     C55, C56       2    101,252.0      16,941.0
#                    Sicilian Defense: Scheveningen Variation, Classical Variation          2                     B83, B84       2    100,909.0      10,919.0
#                                              Old Indian Defense: Czech Variation          2                     A46, A53       2     94,700.0      14,051.0
#                  Sicilian Defense: Smith-Morra Gambit Declined, Center Formation          2                     B21, B22       2     93,612.0      16,668.0
#                                    Italian Game: Scotch Gambit, Janowski Defense          2                     C55, C56       2     81,851.0      17,232.0
#                                        Queen's Gambit Declined: Vienna Variation          2                     D30, D37       2     78,934.0      17,481.0
#                                  Italian Game: Scotch Gambit, de Riviere Defense          2                     C55, C56       2     73,147.0      17,101.0
#                 King's Gambit Declined: Falkbeer Countergambit, Charousek Gambit          2                     C31, C32       2     70,692.0       6,416.0
#                                       Queen's Indian Defense: Kasparov Variation          2                     E12, E13       2     70,472.0      11,160.0
#                                         King's Indian Defense: Sämisch Variation          2                     E80, E86       2     69,753.0       9,074.0
#                 Italian Game: Scotch Gambit, Max Lange Attack, Spielmann Defense          2                     C55, C56       2     69,077.0      15,134.0
#                                                   Dutch Defense: Staunton Gambit          2                     A82, A83       2     67,748.0       9,657.0
#                                  French Defense: Tarrasch Variation, Open System          2                     C07, C08       2     66,956.0      10,241.0
#                                              French Defense: Classical Variation          2                     C11, C14       2     65,100.0      17,930.0
# English Opening: Symmetrical Variation, Anti-Benoni Variation, Spielmann Defense          2                     A32, A33       2     64,811.0      14,095.0
#                                                           Queen's Indian Defense          2                     A47, E12       2     57,341.0      11,005.0
#                                 Blackmar-Diemer Gambit Declined: O'Kelly Defense          2                     A45, D00       2     56,043.0      11,434.0
#                                             St. George Defense: Polish Variation          2                     A40, B00       2     55,740.0      17,170.0
#                               Italian Game: Scotch Gambit, Walbrodt-Baird Gambit          2                     C53, C56       2     55,525.0      14,796.0
#                             Dutch Defense: Stonewall Variation, Modern Variation          2                     A40, A90       2     53,295.0       6,291.0
#                                  Italian Game: Classical Variation, Greco Gambit          2                     C53, C54       2     51,398.0       8,778.0
#                                   Nimzo-Indian Defense: St. Petersburg Variation          2                     E43, E44       2     41,545.0       7,150.0
#                                       Sicilian Defense: Richter-Rauzer Variation          2                     B60, B62       2     41,013.0       9,505.0
#                                               French Defense: Diemer-Duhm Gambit          2                     C00, D30       2     40,929.0      14,361.0
#                         Sicilian Defense: Scheveningen Variation, English Attack          2                     B80, B90       2     40,316.0       5,431.0
#                                                       Italian Game: Evans Gambit          2                     C51, C52       2     40,201.0       9,464.0
#                                               French Defense: Franco-Hiva Gambit          2                     A82, C00       2     38,619.0      16,359.0
#                  English Opening: Anglo-Indian Defense, Queen's Indian Formation          2                     A15, A17       2     38,368.0       8,189.0
#                                                                  Ruy Lopez: Open          2                     C80, C82       2     36,001.0       5,180.0
#                                     King's Gambit Accepted: King Knight's Gambit          2                     C34, C39       2     34,670.0       7,633.0
#                                              Benoni Defense: Classical Variation          2                     A70, A72       2     32,179.0       5,788.0
#                             Queen's Gambit Declined: Orthodox Defense, Main Line          2                     D63, D67       2     30,339.0       6,934.0
#                                      Queen's Gambit Declined: Tartakower Defense          2                     D58, D59       2     27,799.0       4,260.0
#                                                      Italian Game: Scotch Gambit          2                     C55, C56       2     25,911.0       8,560.0
#                                            Old Indian Defense: Tartakower-Indian          2                     A46, A54       2     25,483.0       9,029.0
#                                          Queen's Gambit Declined: Lasker Defense          2                     D53, D56       2     22,851.0       7,206.0
#             Italian Game: Classical Variation, Greco Gambit, Anderssen Variation          2                     C53, C54       2     22,339.0       4,771.0
#                                       Nimzo-Indian Defense: Romanishin Variation          2                     E20, E21       2     22,255.0       5,397.0
#                                          Sicilian Defense: Boleslavsky Variation          2                     B58, B59       2     21,482.0       5,310.0
#                                               Semi-Slav Defense: Meran Variation          2                     D47, D48       2     20,957.0       4,630.0
#                              Queen's Gambit Declined: Orthodox Defense, Bd3 Line          2                     D66, D67       2     19,023.0       5,135.0
#                                             Benoni Defense: Fianchetto Variation          2                     A61, A62       2     16,044.0       2,651.0
#                                               Dutch Defense: Leningrad Variation          2                     A86, A87       2     15,572.0       3,595.0
#                     King's Indian Defense: Fianchetto Variation, Yugoslav System          2                     E60, E64       2     15,462.0       4,390.0
#                                          Nimzo-Indian Defense: Rubinstein System          2                     E40, E41       2     14,438.0       4,646.0
#                         Polish Opening: King's Indian Variation, Sokolsky Attack          2                     A00, A15       2     12,574.0       4,268.0
#                                              Grünfeld Defense: Russian Variation          2                     D96, D97       2     12,415.0       2,157.0
#                               Modern Defense: Averbakh Variation, Pseudo-Sämisch          2                     A10, A42       2     12,207.0       4,476.0
#                                             King's Gambit Accepted: Greco Gambit          2                     C34, C38       2     11,834.0       2,979.0
#                                           Nimzo-Indian Defense: Normal Variation          2                     E46, E47       2     11,700.0       4,065.0
#                                 King's Pawn Game: Clam Variation, Radisch Gambit          2                     B02, C20       2     10,922.0       4,397.0
#                 Sicilian Defense: Richter-Rauzer Variation, Neo-Modern Variation          2                     B67, B68       2     10,528.0       1,472.0
#            Italian Game: Two Knights Defense, Max Lange Attack, Krause Variation          2                     C55, C56       2     10,426.0       4,949.0
#                                  Queen's Gambit Declined: Neo-Orthodox Variation          2                     D54, D55       2     10,304.0       4,064.0
#                          Dutch Defense: Classical Variation, Stonewall Variation          2                     A94, A95       2      9,237.0       2,541.0
#                     Sicilian Defense: Richter-Rauzer Variation, Modern Variation          2                     B60, B61       2      8,650.0       2,718.0
#                                                       Ruy Lopez: Noah's Ark Trap          2                     C71, C88       2      8,489.0       2,377.0
#                                               Modern Defense: Neo-Modern Defense          2                     A10, A41       2      7,921.0       4,312.0
#                     Queen's Gambit Declined: Orthodox Defense, Rubinstein Attack          2                     D64, D65       2      7,877.0       2,712.0
#                English Opening: Symmetrical Variation, Botvinnik System Reversed          2                     A36, A37       2      7,581.0       1,989.0
#                                             Caro-Kann Defense: Finnish Variation          2                     B15, B16       2      7,174.0       3,104.0
#                                                Ruy Lopez: Closed, Closed Defense          2                     C90, C96       2      6,966.0       2,252.0
#                                           English Opening: Achilles-Omega Gambit          2                     A10, B02       2      6,091.0       3,216.0
#                 King's Indian Defense: Fianchetto Variation, Hungarian Variation          2                     E64, E67       2      6,037.0       2,529.0
#                           Italian Game: Scotch Gambit, Max Lange Attack Accepted          2                     C55, C56       2      5,969.0       2,721.0
#                    Italian Game: Scotch Gambit, Max Lange Attack, Long Variation          2                     C55, C56       2      5,371.0         976.0
#              King's Indian Defense: Semi-Classical Variation, Exchange Variation          2                     A10, E61       2      5,131.0       2,365.0
#                                Italian Game: Giuoco Piano, Rosentreter Variation          2                     C54, C55       2      4,484.0       1,351.0
#                                    Philidor Defense: Lion Variation, Lion's Claw          2                     B07, C41       2      4,126.0       1,859.0
#                                              Van Geet Opening: Nowokunski Gambit          2                     A00, C33       2      3,822.0       2,343.0
#            King's Indian Defense: Fianchetto Variation, Double Fianchetto Attack          2                     E64, E67       2      2,611.0       1,040.0
#                                                 Ruy Lopez: Closed, Keres Defense          2                     C92, C96       2      2,503.0         864.0
#                                                  Dutch Defense: Krause Variation          2                     A10, A84       2      2,474.0       1,709.0
#                    King's Indian Defense: Fianchetto Variation, Benjamin Defense          2                     A49, E61       2      2,458.0       1,002.0
#                                     Zukertort Defense: Sicilian Knight Variation          2                     A04, B00       2      1,977.0       1,282.0
#                        English Opening: Anglo-Indian Defense, Grünfeld Formation          2                     A07, A15       2      1,750.0         875.0
#                                              Horwitz Defense: Zilbermints Gambit          2                     A13, A40       2      1,388.0       1,128.0
#                                            Zukertort Defense: Kingside Variation          2                     A04, A40       2      1,332.0         799.0
#                   Queen's Gambit Declined: Orthodox Defense, Classical Variation          2                     D68, D69       2      1,322.0         595.0
#                                                Ruy Lopez: Closed, Breyer Defense          2                     C94, C95       2      1,166.0         513.0
#                           Grünfeld Defense: Russian Variation, Smyslov Variation          2                     D98, D99       2      1,060.0         356.0
#               Italian Game: Two Knights Defense, Max Lange Attack, Loman Defense          2                     C55, C56       2        975.0         334.0
#                                    Italian Game: Giuoco Piano, Holzhausen Attack          2                     C54, C55       2        695.0         379.0
#                                                  Dutch Defense: Senechaud Gambit          2                     A40, A80       2        686.0         324.0
#                  Italian Game: Classical Variation, Giuoco Pianissimo, Main Line          2                     C53, C54       2        571.0         364.0
#                           Italian Game: Two Knights Defense, Keidansky Variation          2                     C55, C56       2        409.0         272.0
#        Italian Game: Two Knights Defense, Max Lange Attack, Rubinstein Variation          2                     C55, C56       2        354.0         188.0
#                          Queen's Pawn Game: London System, Pterodactyl Variation          2                     A40, D02       2        305.0         232.0
#                       Nimzo-Indian Defense: Romanishin Variation, English Hybrid          2                     E20, E21       2        294.0         188.0
#            Italian Game: Two Knights Defense, Max Lange Attack, Berger Variation          2                     C55, C56       2        121.0          82.0
#               King's Indian Defense: Fianchetto Variation, Pterodactyl Variation          2                     E60, E64       2         66.0          43.0
#
# === DETAILED BREAKDOWN FOR TOP 10 MOST COMPLEX CASES ===
#
# --- 'Nimzo-Indian Defense: Sämisch Variation' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# E27    29,709.0   6,286    15,594.0       50.00    14,115.0       45.60
# E24    13,965.0   3,657     6,979.0       46.80     6,986.0       47.00
# E26    10,416.0   2,633     5,475.0       48.80     4,941.0       45.80
# E28     7,112.0   2,637     3,966.0       49.60     3,146.0       44.90
# E25     2,857.0     722     1,448.0       53.70     1,409.0       40.00
# E29     1,688.0     649       986.0       54.90       702.0       41.20
#
# --- 'Sicilian Defense: Najdorf Variation' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# B90   426,604.0  17,588   218,704.0       47.20   207,900.0       48.20
# B95   153,154.0  11,216    74,579.0       47.60    78,575.0       49.10
# B94   133,751.0  10,386    68,584.0       49.20    65,167.0       46.70
# B98    47,983.0   4,573    24,455.0       51.20    23,528.0       44.60
# B96    31,769.0   2,480    16,770.0       48.50    14,999.0       45.90
#
# --- 'Ruy Lopez: Morphy Defense, Modern Steinitz Defense' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# C71    75,470.0  11,001    32,661.0       50.40    42,809.0       44.20
# C72    68,839.0   9,502    28,946.0       48.80    39,893.0       46.30
# C74    52,785.0   8,490    25,806.0       52.70    26,979.0       42.70
# C75    18,184.0   5,231     8,686.0       51.00     9,498.0       43.80
# C73     3,790.0   1,114     1,875.0       49.30     1,915.0       43.30
#
# --- 'Dutch Defense: Classical Variation' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# A84   109,526.0  10,357    52,864.0       48.30    56,662.0       46.40
# A90    28,240.0   4,802    12,674.0       48.40    15,566.0       44.20
# A96    12,597.0   2,549     5,785.0       50.80     6,812.0       42.90
# A91     8,200.0   2,306     3,827.0       48.30     4,373.0       44.00
# A92     6,408.0   2,219     2,899.0       51.50     3,509.0       43.50
#
# --- 'Sicilian Defense: Closed' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# B23 2,896,038.0  33,329 1,446,074.0       49.60 1,449,964.0       45.60
# B24   123,506.0   6,858    68,527.0       50.80    54,979.0       42.60
# B25    39,909.0   4,963    20,843.0       49.40    19,066.0       43.50
# B26    28,753.0   3,379    14,292.0       52.30    14,461.0       41.40
#
# --- 'King's Indian Defense: Orthodox Variation' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# E91   283,922.0  15,792   141,713.0       49.80   142,209.0       44.90
# E94    18,173.0   2,350    10,503.0       44.70     7,670.0       46.60
# E95     6,578.0   1,205     3,782.0       49.60     2,796.0       44.20
# E92     3,026.0   1,205     1,720.0       50.30     1,306.0       45.60
#
# --- 'Catalan Opening: Closed' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# E06   127,603.0  10,984    58,448.0       49.50    69,155.0       42.10
# E01    82,704.0  15,183    34,561.0       50.60    48,143.0       42.10
# E07    16,064.0   3,482     7,120.0       48.90     8,944.0       43.30
# E08    11,819.0   2,929     5,136.0       49.70     6,683.0       40.90
#
# --- 'French Defense: Winawer Variation, Advance Variation' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# C16    76,989.0  12,546    37,060.0       50.50    39,929.0       44.30
# C17    46,024.0   7,816    23,755.0       47.10    22,269.0       47.40
# C18    34,068.0   4,562    17,513.0       48.90    16,555.0       46.20
# C19    24,273.0   2,576    12,510.0       47.70    11,763.0       46.40
#
# --- 'Sicilian Defense: Dragon Variation, Yugoslav Attack' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# B76    54,005.0   7,145    27,805.0       51.70    26,200.0       44.60
# B78    19,769.0   2,638     9,119.0       47.50    10,650.0       48.10
# B77    18,822.0   2,543     9,863.0       47.50     8,959.0       46.40
# B79     1,031.0     304       463.0       44.30       568.0       52.30
#
# --- 'Ruy Lopez: Closed' ---
# ECO Total Games Players White Games  White Win% Black Games  Black Win%
# C88    58,062.0   5,245    27,680.0       49.10    30,382.0       44.50
# C84    27,838.0   4,292    12,834.0       50.60    15,004.0       43.10
# C92     2,175.0   1,343     1,086.0       53.40     1,089.0       38.80
# C90       978.0     511       425.0       49.20       553.0       44.50
#
# === SUMMARY STATISTICS ===
# Total opening names with multiple ECO codes: 184
# Maximum ECO codes for single name: 6
# Average ECO codes per duplicated name: 2.3
# Total games affected by name duplication: 122,426,853.0
# Total players affected by name duplication: 3,904,484.0
#
# === POTENTIAL INVESTIGATION AREAS ===
# 1. Names with many ECO codes might indicate:
#    - Opening transpositions (same position reached via different move orders)
#    - Opening variations that are classified separately
#    - Potential data quality issues or inconsistent naming
# 2. Consider consolidating or creating hierarchical relationships
# 3. Review ECO classification standards for these openings
