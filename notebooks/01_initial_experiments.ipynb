# %% [markdown]
# # Purpose:
# To obtain data on lichess games, sort and organize by username, sanitize and sort.

# %%
import chess.pgn
import zstandard as zstd
import io

# Path to the compressed PGN file
pgn_path = "/Users/a/Documents/personalprojects/chess-opening-recommender/data/raw/lichess_db_standard_rated_2025-07.pgn.zst"

# Open and decompress the file
with open(pgn_path, 'rb') as f:
    dctx = zstd.ZstdDecompressor()
    stream_reader = dctx.stream_reader(f)
    text_stream = io.TextIOWrapper(stream_reader, encoding='utf-8')
    
    # Read the first game as an example
    game = chess.pgn.read_game(text_stream)
    
    # Print the game details
    if game:
        print(f"Event: {game.headers['Event']}")
        print(f"White: {game.headers['White']} (Elo: {game.headers.get('WhiteElo', 'N/A')})")
        print(f"Black: {game.headers['Black']} (Elo: {game.headers.get('BlackElo', 'N/A')})")
        print(f"Result: {game.headers['Result']}")
        print(f"Opening: {game.headers.get('Opening', 'N/A')}")
        print(f"ECO: {game.headers.get('ECO', 'N/A')}")
        print(f"\nMoves:")
        print(game)
    else:
        print("No game found in the file.")
# Out:
# Event: Rated Bullet game
# White: my_name_jeff (Elo: 1706)
# Black: xxxgrishaxxx (Elo: 1671)
# Result: 0-1
# Opening: Benoni Defense: Old Benoni
# ECO: A43
#
# Moves:
# [Event "Rated Bullet game"]
# [Site "https://lichess.org/VsUqVhC2"]
# [Date "2025.07.01"]
# [Round "-"]
# [White "my_name_jeff"]
# [Black "xxxgrishaxxx"]
# [Result "0-1"]
# [UTCDate "2025.07.01"]
# [UTCTime "00:00:31"]
# [WhiteElo "1706"]
# [BlackElo "1671"]
# [WhiteRatingDiff "-6"]
# [BlackRatingDiff "+6"]
# [ECO "A43"]
# [Opening "Benoni Defense: Old Benoni"]
# [TimeControl "60+0"]
# [Termination "Time forfeit"]
#
# 1. d4 { [%clk 0:01:00] } 1... c5 { [%clk 0:01:00] } 2. e3 { [%clk 0:01:00] } 2... e6 { [%clk 0:00:59] } 3. dxc5 { [%clk 0:00:59] } 3... Bxc5 { [%clk 0:00:58] } 4. Nf3 { [%clk 0:00:59] } 4... Nf6 { [%clk 0:00:57] } 5. c3 { [%clk 0:00:59] } 5... Nc6 { [%clk 0:00:56] } 6. Bb5 { [%clk 0:00:58] } 6... a6 { [%clk 0:00:55] } 7. Bxc6 { [%clk 0:00:57] } 7... bxc6 { [%clk 0:00:55] } 8. O-O { [%clk 0:00:57] } 8... d5 { [%clk 0:00:54] } 9. Nd4 { [%clk 0:00:56] } 9... Bd7 { [%clk 0:00:52] } 10. Qf3 { [%clk 0:00:53] } 10... O-O { [%clk 0:00:51] } 11. h4 { [%clk 0:00:51] } 11... e5 { [%clk 0:00:50] } 12. Nc2 { [%clk 0:00:50] } 12... Bd6 { [%clk 0:00:49] } 13. h5 { [%clk 0:00:47] } 13... e4 { [%clk 0:00:49] } 14. Qe2 { [%clk 0:00:46] } 14... Bg4 { [%clk 0:00:46] } 15. f3 { [%clk 0:00:43] } 15... exf3 { [%clk 0:00:46] } 16. gxf3 { [%clk 0:00:40] } 16... Bxh5 { [%clk 0:00:45] } 17. e4 { [%clk 0:00:39] } 17... dxe4 { [%clk 0:00:44] } 18. Ne1 { [%clk 0:00:34] } 18... exf3 { [%clk 0:00:42] } 19. Nxf3 { [%clk 0:00:33] } 19... Qd7 { [%clk 0:00:39] } 20. Bg5 { [%clk 0:00:31] } 20... Qg4+ { [%clk 0:00:37] } 21. Qg2 { [%clk 0:00:30] } 21... Qxg2+ { [%clk 0:00:35] } 22. Kxg2 { [%clk 0:00:29] } 22... Bxf3+ { [%clk 0:00:34] } 23. Rxf3 { [%clk 0:00:27] } 23... Ne4 { [%clk 0:00:32] } 24. Be3 { [%clk 0:00:26] } 24... h6 { [%clk 0:00:31] } 25. Nd2 { [%clk 0:00:24] } 25... Rfe8 { [%clk 0:00:30] } 26. Nxe4 { [%clk 0:00:23] } 26... Rxe4 { [%clk 0:00:30] } 27. Bd4 { [%clk 0:00:19] } 27... Rae8 { [%clk 0:00:28] } 28. Raf1 { [%clk 0:00:18] } 28... c5 { [%clk 0:00:27] } 29. Bg1 { [%clk 0:00:16] } 29... f6 { [%clk 0:00:24] } 30. a3 { [%clk 0:00:15] } 30... Re2+ { [%clk 0:00:22] } 31. Bf2 { [%clk 0:00:13] } 31... Rxb2 { [%clk 0:00:21] } 32. Kh3 { [%clk 0:00:09] } 32... Ree2 { [%clk 0:00:20] } 33. Kg2 { [%clk 0:00:07] } 33... c4 { [%clk 0:00:18] } 34. a4 { [%clk 0:00:07] } 34... Bc5 { [%clk 0:00:17] } 35. Re3 { [%clk 0:00:04] } 35... Bxe3 { [%clk 0:00:16] } 0-1

# %%
# Function to read multiple games
def read_games(file_path, max_games=10):
    games = []
    
    with open(file_path, 'rb') as f:
        dctx = zstd.ZstdDecompressor()
        stream_reader = dctx.stream_reader(f)
        text_stream = io.TextIOWrapper(stream_reader, encoding='utf-8')
        
        for _ in range(max_games):
            game = chess.pgn.read_game(text_stream)
            if game is None:
                break
            games.append(game)
    
    return games

# Read 5 games as an example
games = read_games(pgn_path, max_games=200)

# Print basic information about each game
for i, game in enumerate(games, 1):
    print(f"Game {i}:")
    print(f"  White: {game.headers['White']} (Elo: {game.headers.get('WhiteElo', 'N/A')})")
    print(f"  Black: {game.headers['Black']} (Elo: {game.headers.get('BlackElo', 'N/A')})")
    print(f"  Result: {game.headers['Result']}")
    print(f"  ECO: {game.headers.get('ECO', 'N/A')}")
    print()
# Out:
# Game 1:
#   White: my_name_jeff (Elo: 1706)
#   Black: xxxgrishaxxx (Elo: 1671)
#   Result: 0-1
#   ECO: A43
#
# Game 2:
#   White: Lostratega (Elo: 2262)
#   Black: abdo0diab2000 (Elo: 2191)
#   Result: 1-0
#   ECO: A46
#
# Game 3:
#   White: YarnHugen (Elo: 2279)
#   Black: LateralusMind (Elo: 2339)
#   Result: 0-1
#   ECO: A46
#
# Game 4:
#   White: Timon_01 (Elo: 971)
#   Black: tbruins82 (Elo: 1040)
#   Result: 0-1
#   ECO: A00
#
# Game 5:
#   White: birddead (Elo: 1752)
#   Black: jay623 (Elo: 1737)
#   Result: 0-1
#   ECO: C41
#
# Game 6:
#   White: a_Random_Rook (Elo: 1786)
#   Black: Tomorrow_Man (Elo: 1801)
#   Result: 0-1
#   ECO: B00
#
# Game 7:
#   White: ale_998 (Elo: 1144)
#   Black: ArtyCranner (Elo: 1125)
#   Result: 0-1
#   ECO: A00
#
# Game 8:
#   White: likerszap (Elo: 1950)
#   Black: vincgrandmaster (Elo: 1946)
#   Result: 0-1
#   ECO: A00
#
# Game 9:
#   White: br0ze-YT (Elo: 1579)
#   Black: QueenPalestine (Elo: 1511)
#   Result: 1-0
#   ECO: A05
#
# Game 10:
#   White: peakfallenn (Elo: 1820)
#   Black: qmrtll (Elo: 1850)
#   Result: 1-0
#   ECO: A40
#
# Game 11:
#   White: randy-6500 (Elo: 890)
#   Black: salutsashaa (Elo: 878)
#   Result: 0-1
#   ECO: C55
#
# Game 12:
#   White: KaanSondal (Elo: 1346)
#   Black: TETONUNKOCASI54 (Elo: 1411)
#   Result: 1-0
#   ECO: B01
#
# Game 13:
#   White: omniscient_pants (Elo: 1855)
#   Black: ricardorst (Elo: 1888)
#   Result: 0-1
#   ECO: D00
#
# Game 14:
#   White: mike_flotsam (Elo: 2064)
#   Black: NandoFlow (Elo: 2064)
#   Result: 1-0
#   ECO: D30
#
# Game 15:
#   White: nEiL_lAd (Elo: 2652)
#   Black: Tiger-DLH (Elo: 2770)
#   Result: 1-0
#   ECO: B23
#
# Game 16:
#   White: xeqtr85 (Elo: 1963)
#   Black: YogiBearBack (Elo: 2027)
#   Result: 0-1
#   ECO: C45
#
# Game 17:
#   White: M4ll4ns0hn (Elo: 1049)
#   Black: JohnnySilence (Elo: 1102)
#   Result: 0-1
#   ECO: D00
#
# Game 18:
#   White: andyziva (Elo: 1933)
#   Black: silverchair (Elo: 1927)
#   Result: 0-1
#   ECO: A40
#
# Game 19:
#   White: Gvozdodyor78 (Elo: 2045)
#   Black: ABuggersLife (Elo: 2126)
#   Result: 1-0
#   ECO: B56
#
# Game 20:
#   White: upstateny (Elo: 2098)
#   Black: FauciChess (Elo: 2125)
#   Result: 0-1
#   ECO: B06
#
# Game 21:
#   White: Giakomo22 (Elo: 1519)
#   Black: xan9xx (Elo: 1544)
#   Result: 1-0
#   ECO: C01
#
# Game 22:
#   White: PRETORGLO (Elo: 2449)
#   Black: Schachgenie (Elo: 2516)
#   Result: 0-1
#   ECO: A00
#
# Game 23:
#   White: outsider92 (Elo: 1941)
#   Black: Vikings00 (Elo: 1924)
#   Result: 1-0
#   ECO: A10
#
# Game 24:
#   White: Roger5Smith (Elo: 1576)
#   Black: ghridjvw (Elo: 1588)
#   Result: 1-0
#   ECO: A00
#
# Game 25:
#   White: vomacrac (Elo: 2315)
#   Black: La_Mistica1 (Elo: 2282)
#   Result: 1-0
#   ECO: E00
#
# Game 26:
#   White: edas (Elo: 1935)
#   Black: Eelzor (Elo: 1988)
#   Result: 1-0
#   ECO: A48
#
# Game 27:
#   White: solange62180 (Elo: 1375)
#   Black: nn1856 (Elo: 1374)
#   Result: 0-1
#   ECO: C50
#
# Game 28:
#   White: SixxPack400 (Elo: 1138)
#   Black: Euby5241 (Elo: 1014)
#   Result: 0-1
#   ECO: C20
#
# Game 29:
#   White: Roi957 (Elo: 1885)
#   Black: BraulioCVP (Elo: 1851)
#   Result: 0-1
#   ECO: D00
#
# Game 30:
#   White: jhankachess (Elo: 1340)
#   Black: Kraftfull (Elo: 1336)
#   Result: 1-0
#   ECO: B01
#
# Game 31:
#   White: Obeevee (Elo: 1654)
#   Black: Melgar1 (Elo: 1701)
#   Result: 0-1
#   ECO: A46
#
# Game 32:
#   White: GabrielGuillen (Elo: 1816)
#   Black: hamed_m (Elo: 1829)
#   Result: 1-0
#   ECO: C30
#
# Game 33:
#   White: johnbuitrago (Elo: 2040)
#   Black: SHARA1313 (Elo: 1995)
#   Result: 0-1
#   ECO: D00
#
# Game 34:
#   White: YSO_2023 (Elo: 1175)
#   Black: Leckw (Elo: 1148)
#   Result: 1-0
#   ECO: C47
#
# Game 35:
#   White: cfalk29 (Elo: 862)
#   Black: Jonathan2453 (Elo: 869)
#   Result: 1-0
#   ECO: A01
#
# Game 36:
#   White: Ignasiherms (Elo: 1484)
#   Black: qknightking (Elo: 1496)
#   Result: 1-0
#   ECO: C50
#
# Game 37:
#   White: Ruyaadam (Elo: 1559)
#   Black: markemoon (Elo: 1562)
#   Result: 1-0
#   ECO: A00
#
# Game 38:
#   White: DancyRaegan (Elo: 1743)
#   Black: Tenkoff_Alex (Elo: 1758)
#   Result: 0-1
#   ECO: C46
#
# Game 39:
#   White: Skandinavos (Elo: 2078)
#   Black: saimonzz1975 (Elo: 2057)
#   Result: 1-0
#   ECO: B00
#
# Game 40:
#   White: boris-mc-savior (Elo: 1443)
#   Black: octaviuuss (Elo: 1469)
#   Result: 1-0
#   ECO: C45
#
# Game 41:
#   White: Npxh (Elo: 1407)
#   Black: Albadry (Elo: 1435)
#   Result: 1-0
#   ECO: B01
#
# Game 42:
#   White: NAveevAN (Elo: 1894)
#   Black: ajedrezferni (Elo: 1912)
#   Result: 1-0
#   ECO: B20
#
# Game 43:
#   White: luis8730 (Elo: 1433)
#   Black: Pablooo456 (Elo: 1409)
#   Result: 1-0
#   ECO: C62
#
# Game 44:
#   White: candelier (Elo: 1764)
#   Black: EwanMellor (Elo: 1767)
#   Result: 0-1
#   ECO: C41
#
# Game 45:
#   White: Matejbisevac1 (Elo: 1348)
#   Black: Marcelogu (Elo: 1348)
#   Result: 1-0
#   ECO: A22
#
# Game 46:
#   White: savageactual (Elo: 1524)
#   Black: RobertPearson (Elo: 1543)
#   Result: 1-0
#   ECO: B20
#
# Game 47:
#   White: B6C (Elo: 1100)
#   Black: jperkins (Elo: 1119)
#   Result: 0-1
#   ECO: A07
#
# Game 48:
#   White: meybsky (Elo: 1408)
#   Black: Woodchuck1 (Elo: 1338)
#   Result: 1-0
#   ECO: C24
#
# Game 49:
#   White: lucioaneo (Elo: 2045)
#   Black: Doge_Dandolo (Elo: 2082)
#   Result: 0-1
#   ECO: B03
#
# Game 50:
#   White: sifumaster13 (Elo: 1191)
#   Black: raggiotto (Elo: 1220)
#   Result: 0-1
#   ECO: C26
#
# Game 51:
#   White: Mikhail153 (Elo: 1340)
#   Black: rwildernessr (Elo: 1340)
#   Result: 1-0
#   ECO: B13
#
# Game 52:
#   White: Medica_louca (Elo: 1626)
#   Black: amin_1985_1364 (Elo: 1732)
#   Result: 0-1
#   ECO: B10
#
# Game 53:
#   White: Donlarje (Elo: 1740)
#   Black: jcornejofu (Elo: 1740)
#   Result: 1-0
#   ECO: B01
#
# Game 54:
#   White: londono_123 (Elo: 1241)
#   Black: CLSfrog (Elo: 1272)
#   Result: 0-1
#   ECO: B00
#
# Game 55:
#   White: jayfire_1 (Elo: 1659)
#   Black: ferupe (Elo: 1629)
#   Result: 0-1
#   ECO: A40
#
# Game 56:
#   White: Arashirani (Elo: 1328)
#   Black: JonathanMBEP (Elo: 1163)
#   Result: 0-1
#   ECO: B00
#
# Game 57:
#   White: KingOf64_2014 (Elo: 2107)
#   Black: chiky-bustamante (Elo: 2062)
#   Result: 1-0
#   ECO: B15
#
# Game 58:
#   White: checchec (Elo: 1371)
#   Black: jjvasfon (Elo: 1297)
#   Result: 0-1
#   ECO: C60
#
# Game 59:
#   White: JuicyKetchup (Elo: 2451)
#   Black: dky99 (Elo: 2378)
#   Result: 0-1
#   ECO: A13
#
# Game 60:
#   White: Kiril12345 (Elo: 2727)
#   Black: makeareason (Elo: 2768)
#   Result: 1-0
#   ECO: A01
#
# Game 61:
#   White: j-o-a-o_v-i-t-o-r (Elo: 1076)
#   Black: Thirdnight (Elo: 1946)
#   Result: 0-1
#   ECO: C62
#
# Game 62:
#   White: Kuphel (Elo: 2034)
#   Black: chesshuman1 (Elo: 1875)
#   Result: 1-0
#   ECO: C50
#
# Game 63:
#   White: nurbek5 (Elo: 1845)
#   Black: tilsonelfilosofo (Elo: 1567)
#   Result: 1-0
#   ECO: C00
#
# Game 64:
#   White: nampar (Elo: 1727)
#   Black: legennigel (Elo: 2008)
#   Result: 0-1
#   ECO: B10
#
# Game 65:
#   White: SpheM (Elo: 1154)
#   Black: Na99er (Elo: 1111)
#   Result: 1-0
#   ECO: C40
#
# Game 66:
#   White: LuisXavi2015 (Elo: 1107)
#   Black: Rodrigo7221 (Elo: 1067)
#   Result: 1-0
#   ECO: C40
#
# Game 67:
#   White: Sanjuo (Elo: 930)
#   Black: AishikG (Elo: 730)
#   Result: 1-0
#   ECO: C25
#
# Game 68:
#   White: Cturner711 (Elo: 1940)
#   Black: ODBAM (Elo: 1926)
#   Result: 0-1
#   ECO: B02
#
# Game 69:
#   White: amir1983 (Elo: 1809)
#   Black: NullRobot (Elo: 1789)
#   Result: 1/2-1/2
#   ECO: B01
#
# Game 70:
#   White: TheRandyBobandy (Elo: 1153)
#   Black: ShieldToad (Elo: 1163)
#   Result: 0-1
#   ECO: C55
#
# Game 71:
#   White: michaelvsk (Elo: 1393)
#   Black: Paul_Ch4vez (Elo: 1398)
#   Result: 1/2-1/2
#   ECO: B00
#
# Game 72:
#   White: ifyouonlyknew33 (Elo: 1436)
#   Black: mukuchess99 (Elo: 1504)
#   Result: 1-0
#   ECO: B40
#
# Game 73:
#   White: Tito69 (Elo: 1995)
#   Black: Elponycraak (Elo: 2003)
#   Result: 0-1
#   ECO: D02
#
# Game 74:
#   White: ismailcinar (Elo: 1588)
#   Black: xiyz8436 (Elo: 1466)
#   Result: 0-1
#   ECO: C50
#
# Game 75:
#   White: DioAstore (Elo: 2047)
#   Black: manjo1914 (Elo: 2036)
#   Result: 1-0
#   ECO: E61
#
# Game 76:
#   White: osaka_is_sleeping (Elo: 1858)
#   Black: jaiden3KG (Elo: 1879)
#   Result: 1-0
#   ECO: B33
#
# Game 77:
#   White: nordiics (Elo: 1991)
#   Black: JackVox (Elo: 1941)
#   Result: 1-0
#   ECO: A05
#
# Game 78:
#   White: Musa_Polat (Elo: 1819)
#   Black: gokuysamantha (Elo: 1819)
#   Result: 0-1
#   ECO: A10
#
# Game 79:
#   White: habana-ajedrez (Elo: 1835)
#   Black: muidrahman92 (Elo: 1923)
#   Result: 1-0
#   ECO: D06
#
# Game 80:
#   White: LesterFreamon (Elo: 1309)
#   Black: braininovertime (Elo: 1340)
#   Result: 1-0
#   ECO: D00
#
# Game 81:
#   White: garez_ng (Elo: 1675)
#   Black: Luchissimo (Elo: 1777)
#   Result: 0-1
#   ECO: A40
#
# Game 82:
#   White: maranhense01 (Elo: 2065)
#   Black: RoyalBengalTiger (Elo: 2108)
#   Result: 0-1
#   ECO: C25
#
# Game 83:
#   White: Luncurhitam (Elo: 2117)
#   Black: patsalo (Elo: 2126)
#   Result: 0-1
#   ECO: B06
#
# Game 84:
#   White: lordenmarious (Elo: 1041)
#   Black: malf0 (Elo: 1033)
#   Result: 0-1
#   ECO: C02
#
# Game 85:
#   White: jurdj01 (Elo: 1232)
#   Black: Andrei-32 (Elo: 1198)
#   Result: 0-1
#   ECO: C20
#
# Game 86:
#   White: Wani122 (Elo: 2042)
#   Black: wakayawaka (Elo: 2063)
#   Result: 1-0
#   ECO: A40
#
# Game 87:
#   White: Oizraelson (Elo: 1347)
#   Black: shirayukihayome (Elo: 1392)
#   Result: 0-1
#   ECO: B33
#
# Game 88:
#   White: Miguelhuevero (Elo: 1748)
#   Black: profiterol (Elo: 1710)
#   Result: 1-0
#   ECO: B08
#
# Game 89:
#   White: feras45555 (Elo: 1336)
#   Black: Revansch (Elo: 1241)
#   Result: 1-0
#   ECO: C23
#
# Game 90:
#   White: standbike (Elo: 1052)
#   Black: amrabel1 (Elo: 953)
#   Result: 1/2-1/2
#   ECO: C40
#
# Game 91:
#   White: Ril14 (Elo: 1189)
#   Black: Dmitri_CA (Elo: 1196)
#   Result: 0-1
#   ECO: C21
#
# Game 92:
#   White: CrystalShyps (Elo: 1429)
#   Black: salvo57 (Elo: 1425)
#   Result: 0-1
#   ECO: D00
#
# Game 93:
#   White: Hermes1972 (Elo: 1152)
#   Black: Ippolo (Elo: 1161)
#   Result: 1-0
#   ECO: C24
#
# Game 94:
#   White: anaszetoun (Elo: 1397)
#   Black: willgor (Elo: 1602)
#   Result: 0-1
#   ECO: C37
#
# Game 95:
#   White: NSLawyer (Elo: 2139)
#   Black: VinRabino (Elo: 2134)
#   Result: 1-0
#   ECO: B00
#
# Game 96:
#   White: Kevkolas (Elo: 1299)
#   Black: kakashirrete_sensei (Elo: 1232)
#   Result: 0-1
#   ECO: B01
#
# Game 97:
#   White: OsiasPortel (Elo: 1763)
#   Black: rolandobrazil (Elo: 1835)
#   Result: 1-0
#   ECO: B06
#
# Game 98:
#   White: malonepracinha (Elo: 1763)
#   Black: oNekinho38 (Elo: 1661)
#   Result: 1-0
#   ECO: C30
#
# Game 99:
#   White: abdulrahmanadil (Elo: 1021)
#   Black: NeelRanjanX (Elo: 1209)
#   Result: 0-1
#   ECO: C50
#
# Game 100:
#   White: Saanvi_soma (Elo: 934)
#   Black: VivaanPK (Elo: 807)
#   Result: 1-0
#   ECO: C57
#
# Game 101:
#   White: elreyenigma02 (Elo: 2146)
#   Black: xCapa_Negrax (Elo: 2168)
#   Result: 0-1
#   ECO: A40
#
# Game 102:
#   White: Rudysw (Elo: 1057)
#   Black: skp92 (Elo: 960)
#   Result: 1-0
#   ECO: A00
#
# Game 103:
#   White: Black_Kamen_Riden (Elo: 1591)
#   Black: PL931101 (Elo: 1568)
#   Result: 0-1
#   ECO: B01
#
# Game 104:
#   White: RashidGad (Elo: 1518)
#   Black: HumbertoSalazar (Elo: 1518)
#   Result: 0-1
#   ECO: C20
#
# Game 105:
#   White: Luigi1969 (Elo: 1073)
#   Black: krkooo (Elo: 1061)
#   Result: 1-0
#   ECO: B00
#
# Game 106:
#   White: ahmedokail23 (Elo: 1104)
#   Black: Arcan33 (Elo: 1120)
#   Result: 1-0
#   ECO: C23
#
# Game 107:
#   White: scorpio2022 (Elo: 2425)
#   Black: Eyes0pen (Elo: 2246)
#   Result: 1-0
#   ECO: B12
#
# Game 108:
#   White: Chumbix (Elo: 1333)
#   Black: Dinamofanat (Elo: 1328)
#   Result: 1-0
#   ECO: C41
#
# Game 109:
#   White: abypowers (Elo: 1689)
#   Black: porcopinco (Elo: 1694)
#   Result: 0-1
#   ECO: B06
#
# Game 110:
#   White: lisa_levi (Elo: 1375)
#   Black: jmaksauce7 (Elo: 1340)
#   Result: 1-0
#   ECO: C40
#
# Game 111:
#   White: Daliso2183 (Elo: 1714)
#   Black: zmarx1 (Elo: 1696)
#   Result: 1-0
#   ECO: D02
#
# Game 112:
#   White: asierraalta7 (Elo: 1738)
#   Black: KenanNur (Elo: 1747)
#   Result: 1-0
#   ECO: D30
#
# Game 113:
#   White: bfhjb (Elo: 1438)
#   Black: RaogoWed (Elo: 1405)
#   Result: 1-0
#   ECO: B27
#
# Game 114:
#   White: JuanDa97 (Elo: 1234)
#   Black: Ryofio (Elo: 1182)
#   Result: 0-1
#   ECO: C50
#
# Game 115:
#   White: madman1988 (Elo: 1641)
#   Black: vampirrrre (Elo: 1632)
#   Result: 1-0
#   ECO: B20
#
# Game 116:
#   White: raoul_duke69 (Elo: 1256)
#   Black: wendelnixon (Elo: 1285)
#   Result: 0-1
#   ECO: C65
#
# Game 117:
#   White: alejandro123halekine (Elo: 1774)
#   Black: senang123 (Elo: 1826)
#   Result: 1-0
#   ECO: B13
#
# Game 118:
#   White: Mentalese (Elo: 2283)
#   Black: elmaestttro (Elo: 2271)
#   Result: 0-1
#   ECO: A06
#
# Game 119:
#   White: Tumuyuki (Elo: 1083)
#   Black: ArianXD (Elo: 1085)
#   Result: 1-0
#   ECO: C57
#
# Game 120:
#   White: JohnDannyJ (Elo: 1688)
#   Black: andreaskano6 (Elo: 1711)
#   Result: 1-0
#   ECO: C44
#
# Game 121:
#   White: Arno-Dorian-Gray (Elo: 1672)
#   Black: fulvioswww (Elo: 1634)
#   Result: 0-1
#   ECO: A00
#
# Game 122:
#   White: Mychessclass (Elo: 2664)
#   Black: ReinaldoR (Elo: 2615)
#   Result: 1-0
#   ECO: C31
#
# Game 123:
#   White: kn1ghtr1der (Elo: 1729)
#   Black: necky0 (Elo: 1718)
#   Result: 1-0
#   ECO: C22
#
# Game 124:
#   White: kangahmad (Elo: 2380)
#   Black: Danna_Revelo (Elo: 2272)
#   Result: 0-1
#   ECO: C50
#
# Game 125:
#   White: Ragnarson13 (Elo: 2010)
#   Black: Caruamnik (Elo: 1951)
#   Result: 0-1
#   ECO: A05
#
# Game 126:
#   White: Jian_lie04 (Elo: 1878)
#   Black: mh_1010 (Elo: 1880)
#   Result: 1-0
#   ECO: D02
#
# Game 127:
#   White: melikeye (Elo: 1155)
#   Black: St3v3nMC198666 (Elo: 1145)
#   Result: 1-0
#   ECO: C00
#
# Game 128:
#   White: kodam64 (Elo: 1587)
#   Black: jasaenzl (Elo: 1586)
#   Result: 0-1
#   ECO: A03
#
# Game 129:
#   White: keissybella (Elo: 1707)
#   Black: Luis_Borbon (Elo: 1783)
#   Result: 1-0
#   ECO: D22
#
# Game 130:
#   White: Jeabs_BG (Elo: 1500)
#   Black: Lubecha (Elo: 1500)
#   Result: 1-0
#   ECO: A06
#
# Game 131:
#   White: nowheremen (Elo: 1500)
#   Black: Jeycat-08 (Elo: 1500)
#   Result: 0-1
#   ECO: ?
#
# Game 132:
#   White: Lydsa55_1 (Elo: 1500)
#   Black: Gata11 (Elo: 1500)
#   Result: 1-0
#   ECO: A10
#
# Game 133:
#   White: emiliaye (Elo: 1500)
#   Black: Ziro64 (Elo: 1500)
#   Result: 0-1
#   ECO: A00
#
# Game 134:
#   White: cHAkAliTTtA (Elo: 1500)
#   Black: Arani1 (Elo: 1500)
#   Result: 1-0
#   ECO: A40
#
# Game 135:
#   White: DanteAthemFudo31 (Elo: 1500)
#   Black: RIVAOU (Elo: 1500)
#   Result: 0-1
#   ECO: ?
#
# Game 136:
#   White: PRINCESA2210 (Elo: 1500)
#   Black: Oscar_Gustavo_1 (Elo: 1500)
#   Result: 0-1
#   ECO: A00
#
# Game 137:
#   White: Javier1319 (Elo: 1135)
#   Black: Jak_FHer (Elo: 1500)
#   Result: 0-1
#   ECO: ?
#
# Game 138:
#   White: Giovany_RC_3012 (Elo: 1003)
#   Black: tony_hrndz (Elo: 593)
#   Result: 1-0
#   ECO: C25
#
# Game 139:
#   White: Clayboard (Elo: 2242)
#   Black: OjaiJoao (Elo: 2601)
#   Result: 0-1
#   ECO: A14
#
# Game 140:
#   White: TopLumpyGator (Elo: 2461)
#   Black: Giorbinky (Elo: 2231)
#   Result: 1-0
#   ECO: D02
#
# Game 141:
#   White: twofast4mike (Elo: 2111)
#   Black: TanMiniGoat (Elo: 2212)
#   Result: 0-1
#   ECO: A48
#
# Game 142:
#   White: fayetteville7177 (Elo: 2084)
#   Black: DeepGeek (Elo: 2076)
#   Result: 1-0
#   ECO: B01
#
# Game 143:
#   White: coffeecastle (Elo: 2056)
#   Black: fritzdutter (Elo: 2001)
#   Result: 0-1
#   ECO: B02
#
# Game 144:
#   White: SlOwTuRtlEbAtChU (Elo: 1979)
#   Black: chickenbootyface (Elo: 1991)
#   Result: 0-1
#   ECO: B50
#
# Game 145:
#   White: cxsimpson (Elo: 1824)
#   Black: chessmaster5657586 (Elo: 1931)
#   Result: 0-1
#   ECO: B43
#
# Game 146:
#   White: SchliemannDefense (Elo: 1674)
#   Black: CooperEVBEN (Elo: 1500)
#   Result: 1-0
#   ECO: C02
#
# Game 147:
#   White: seriozha (Elo: 1485)
#   Black: hanvuminhquan (Elo: 1458)
#   Result: 0-1
#   ECO: D00
#
# Game 148:
#   White: juannn1225_23 (Elo: 1209)
#   Black: laurent971 (Elo: 1270)
#   Result: 0-1
#   ECO: ?
#
# Game 149:
#   White: Lutz-Stephanie222222 (Elo: 1363)
#   Black: M1ars (Elo: 1352)
#   Result: 1-0
#   ECO: A00
#
# Game 150:
#   White: PartyPPP (Elo: 1432)
#   Black: marcelo51 (Elo: 1419)
#   Result: 0-1
#   ECO: A00
#
# Game 151:
#   White: wujinyyy (Elo: 1447)
#   Black: ivaniniWR (Elo: 1453)
#   Result: 1/2-1/2
#   ECO: C02
#
# Game 152:
#   White: t5yh65y5yrgyhg65ytyh (Elo: 1417)
#   Black: Cero_a_la_izquierda (Elo: 1413)
#   Result: 1-0
#   ECO: B40
#
# Game 153:
#   White: vivoangelo (Elo: 1395)
#   Black: Vihan2K12 (Elo: 1404)
#   Result: 1-0
#   ECO: B30
#
# Game 154:
#   White: robertacostasiqueira (Elo: 1364)
#   Black: ashwathiyer (Elo: 1370)
#   Result: 0-1
#   ECO: B00
#
# Game 155:
#   White: liapop (Elo: 1350)
#   Black: CallMeSUCH (Elo: 1348)
#   Result: 1-0
#   ECO: D00
#
# Game 156:
#   White: GITARRE-ev (Elo: 1308)
#   Black: MARCIEL1974 (Elo: 1301)
#   Result: 0-1
#   ECO: D20
#
# Game 157:
#   White: Redwingo (Elo: 1191)
#   Black: brodychess17 (Elo: 1179)
#   Result: 1-0
#   ECO: B00
#
# Game 158:
#   White: akshaygupta (Elo: 1129)
#   Black: avasarala (Elo: 1172)
#   Result: 0-1
#   ECO: A45
#
# Game 159:
#   White: JOSEDAVID0402 (Elo: 1120)
#   Black: brsbyd6368 (Elo: 1093)
#   Result: 0-1
#   ECO: A48
#
# Game 160:
#   White: Risuman (Elo: 1027)
#   Black: TexMexx (Elo: 1047)
#   Result: 0-1
#   ECO: A00
#
# Game 161:
#   White: vasilii3 (Elo: 1020)
#   Black: Pigargue (Elo: 978)
#   Result: 1-0
#   ECO: C31
#
# Game 162:
#   White: AndreeGael (Elo: 1263)
#   Black: Faviu1337 (Elo: 1283)
#   Result: 0-1
#   ECO: B06
#
# Game 163:
#   White: Olemukol-Onon (Elo: 1146)
#   Black: RishAvH24 (Elo: 1153)
#   Result: 1-0
#   ECO: A10
#
# Game 164:
#   White: L33tSauce (Elo: 1060)
#   Black: raktdas (Elo: 1032)
#   Result: 1-0
#   ECO: A10
#
# Game 165:
#   White: DukeofAfrica (Elo: 2377)
#   Black: Juancaballo (Elo: 2379)
#   Result: 1-0
#   ECO: D02
#
# Game 166:
#   White: rachidhafidi05 (Elo: 2325)
#   Black: SHARK444 (Elo: 2304)
#   Result: 1-0
#   ECO: D02
#
# Game 167:
#   White: OhNoMyOhNoMy (Elo: 2357)
#   Black: JeraldoZepeda (Elo: 2341)
#   Result: 1-0
#   ECO: A00
#
# Game 168:
#   White: aknod (Elo: 2283)
#   Black: crun17 (Elo: 2279)
#   Result: 1-0
#   ECO: A00
#
# Game 169:
#   White: wynger (Elo: 2173)
#   Black: iigor7 (Elo: 2240)
#   Result: 1-0
#   ECO: B30
#
# Game 170:
#   White: vinod0922 (Elo: 2061)
#   Black: amory777 (Elo: 2111)
#   Result: 0-1
#   ECO: A45
#
# Game 171:
#   White: coolsumeet (Elo: 2040)
#   Black: pepekasparov (Elo: 2042)
#   Result: 1-0
#   ECO: D13
#
# Game 172:
#   White: Friendly_bud (Elo: 2001)
#   Black: D123456789101112 (Elo: 2017)
#   Result: 1-0
#   ECO: A08
#
# Game 173:
#   White: BlackJamaican (Elo: 1999)
#   Black: ramiroxdsiuuuuu (Elo: 1995)
#   Result: 1-0
#   ECO: A45
#
# Game 174:
#   White: chincha_74 (Elo: 1985)
#   Black: pepengboyetbagsik (Elo: 1993)
#   Result: 1-0
#   ECO: B00
#
# Game 175:
#   White: bebopperz (Elo: 1976)
#   Black: VelaskesD (Elo: 1932)
#   Result: 0-1
#   ECO: B02
#
# Game 176:
#   White: beardogg (Elo: 1898)
#   Black: idreamofcheckmate (Elo: 1914)
#   Result: 1-0
#   ECO: A10
#
# Game 177:
#   White: RobertFP (Elo: 1882)
#   Black: Mikez2019 (Elo: 1889)
#   Result: 0-1
#   ECO: B01
#
# Game 178:
#   White: Gotomat (Elo: 1868)
#   Black: BGBG85 (Elo: 1847)
#   Result: 0-1
#   ECO: D35
#
# Game 179:
#   White: naagar2345 (Elo: 1809)
#   Black: GoOjasRaj04A (Elo: 1844)
#   Result: 0-1
#   ECO: A40
#
# Game 180:
#   White: Siux21 (Elo: 1707)
#   Black: Nigerian_Beast (Elo: 1766)
#   Result: 0-1
#   ECO: A00
#
# Game 181:
#   White: klins07 (Elo: 1677)
#   Black: Gustavojackowski (Elo: 1692)
#   Result: 0-1
#   ECO: B01
#
# Game 182:
#   White: PavloKhomenko (Elo: 1649)
#   Black: nilus71 (Elo: 1677)
#   Result: 1-0
#   ECO: B10
#
# Game 183:
#   White: Daniloc88 (Elo: 1492)
#   Black: Jose_Materano (Elo: 1478)
#   Result: 0-1
#   ECO: C45
#
# Game 184:
#   White: DevotedRealChef (Elo: 650)
#   Black: dheeraj700 (Elo: 1424)
#   Result: 0-1
#   ECO: B01
#
# Game 185:
#   White: BobbyFischerE41 (Elo: 1958)
#   Black: monstercofee (Elo: 1656)
#   Result: 1-0
#   ECO: C52
#
# Game 186:
#   White: harlisph (Elo: 1630)
#   Black: vasquezcristian (Elo: 2128)
#   Result: 1-0
#   ECO: B00
#
# Game 187:
#   White: TAKISHO_nagasaky (Elo: 1500)
#   Black: matikender (Elo: 995)
#   Result: 0-1
#   ECO: C46
#
# Game 188:
#   White: jaymemaceio (Elo: 2288)
#   Black: DaniloGasparov (Elo: 1987)
#   Result: 1/2-1/2
#   ECO: D04
#
# Game 189:
#   White: Echo79 (Elo: 1880)
#   Black: basedeestudo (Elo: 1911)
#   Result: 1-0
#   ECO: D00
#
# Game 190:
#   White: mysterious1234 (Elo: 1000)
#   Black: geraldocapivara (Elo: 1245)
#   Result: 0-1
#   ECO: ?
#
# Game 191:
#   White: emaur (Elo: 1824)
#   Black: LucianoRibeiroPaca (Elo: 1500)
#   Result: 1-0
#   ECO: C01
#
# Game 192:
#   White: AdamJr1234 (Elo: 598)
#   Black: viyomdesai (Elo: 513)
#   Result: 1-0
#   ECO: C23
#
# Game 193:
#   White: Ixcamiq (Elo: 1728)
#   Black: shukry (Elo: 1741)
#   Result: 1-0
#   ECO: A00
#
# Game 194:
#   White: Ksource (Elo: 1192)
#   Black: Ernestomcl (Elo: 1235)
#   Result: 0-1
#   ECO: A01
#
# Game 195:
#   White: Da_Story (Elo: 2104)
#   Black: jacksligma (Elo: 2047)
#   Result: 1-0
#   ECO: A40
#
# Game 196:
#   White: orangecrunch (Elo: 1675)
#   Black: aliqtosh (Elo: 1722)
#   Result: 1-0
#   ECO: C48
#
# Game 197:
#   White: benoni93 (Elo: 2045)
#   Black: Novice86 (Elo: 2039)
#   Result: 0-1
#   ECO: D00
#
# Game 198:
#   White: spacetime_limbo (Elo: 2203)
#   Black: Chenkmiester (Elo: 2216)
#   Result: 1-0
#   ECO: B34
#
# Game 199:
#   White: Neverlowcrow (Elo: 2008)
#   Black: kingsisig (Elo: 1961)
#   Result: 0-1
#   ECO: A40
#
# Game 200:
#   White: OdinTor07 (Elo: 1322)
#   Black: QxU1 (Elo: 1275)
#   Result: 1-0
#   ECO: C44

# %%
# Now to filter out games we don't want, and extract only the information we need
# We'll do this bit by bit to make sure we don't mess it up.abs

games_without_moves = []

import copy

for i, game in enumerate(games[0:1], 1):
    print(game)
    # print(len(games[0:100]))
    # Delete the actual moves (1. d4 etc) from a COPY of game, add copy to games_without_moves. We want to keep the original intact
    game_copy = copy.deepcopy(game)  # Create a deep copy of the game
    # Remove all moves by setting the next pointer of the root node to None
    game_copy.mainline = []
    game_copy.mainline_moves = []
    games_without_moves.append(game_copy)
    print(f"Game {i} without moves:")
    print(games_without_moves)
# Out:
# [Event "Rated Bullet game"]
# [Site "https://lichess.org/VsUqVhC2"]
# [Date "2025.07.01"]
# [Round "-"]
# [White "my_name_jeff"]
# [Black "xxxgrishaxxx"]
# [Result "0-1"]
# [UTCDate "2025.07.01"]
# [UTCTime "00:00:31"]
# [WhiteElo "1706"]
# [BlackElo "1671"]
# [WhiteRatingDiff "-6"]
# [BlackRatingDiff "+6"]
# [ECO "A43"]
# [Opening "Benoni Defense: Old Benoni"]
# [TimeControl "60+0"]
# [Termination "Time forfeit"]
#
# 1. d4 { [%clk 0:01:00] } 1... c5 { [%clk 0:01:00] } 2. e3 { [%clk 0:01:00] } 2... e6 { [%clk 0:00:59] } 3. dxc5 { [%clk 0:00:59] } 3... Bxc5 { [%clk 0:00:58] } 4. Nf3 { [%clk 0:00:59] } 4... Nf6 { [%clk 0:00:57] } 5. c3 { [%clk 0:00:59] } 5... Nc6 { [%clk 0:00:56] } 6. Bb5 { [%clk 0:00:58] } 6... a6 { [%clk 0:00:55] } 7. Bxc6 { [%clk 0:00:57] } 7... bxc6 { [%clk 0:00:55] } 8. O-O { [%clk 0:00:57] } 8... d5 { [%clk 0:00:54] } 9. Nd4 { [%clk 0:00:56] } 9... Bd7 { [%clk 0:00:52] } 10. Qf3 { [%clk 0:00:53] } 10... O-O { [%clk 0:00:51] } 11. h4 { [%clk 0:00:51] } 11... e5 { [%clk 0:00:50] } 12. Nc2 { [%clk 0:00:50] } 12... Bd6 { [%clk 0:00:49] } 13. h5 { [%clk 0:00:47] } 13... e4 { [%clk 0:00:49] } 14. Qe2 { [%clk 0:00:46] } 14... Bg4 { [%clk 0:00:46] } 15. f3 { [%clk 0:00:43] } 15... exf3 { [%clk 0:00:46] } 16. gxf3 { [%clk 0:00:40] } 16... Bxh5 { [%clk 0:00:45] } 17. e4 { [%clk 0:00:39] } 17... dxe4 { [%clk 0:00:44] } 18. Ne1 { [%clk 0:00:34] } 18... exf3 { [%clk 0:00:42] } 19. Nxf3 { [%clk 0:00:33] } 19... Qd7 { [%clk 0:00:39] } 20. Bg5 { [%clk 0:00:31] } 20... Qg4+ { [%clk 0:00:37] } 21. Qg2 { [%clk 0:00:30] } 21... Qxg2+ { [%clk 0:00:35] } 22. Kxg2 { [%clk 0:00:29] } 22... Bxf3+ { [%clk 0:00:34] } 23. Rxf3 { [%clk 0:00:27] } 23... Ne4 { [%clk 0:00:32] } 24. Be3 { [%clk 0:00:26] } 24... h6 { [%clk 0:00:31] } 25. Nd2 { [%clk 0:00:24] } 25... Rfe8 { [%clk 0:00:30] } 26. Nxe4 { [%clk 0:00:23] } 26... Rxe4 { [%clk 0:00:30] } 27. Bd4 { [%clk 0:00:19] } 27... Rae8 { [%clk 0:00:28] } 28. Raf1 { [%clk 0:00:18] } 28... c5 { [%clk 0:00:27] } 29. Bg1 { [%clk 0:00:16] } 29... f6 { [%clk 0:00:24] } 30. a3 { [%clk 0:00:15] } 30... Re2+ { [%clk 0:00:22] } 31. Bf2 { [%clk 0:00:13] } 31... Rxb2 { [%clk 0:00:21] } 32. Kh3 { [%clk 0:00:09] } 32... Ree2 { [%clk 0:00:20] } 33. Kg2 { [%clk 0:00:07] } 33... c4 { [%clk 0:00:18] } 34. a4 { [%clk 0:00:07] } 34... Bc5 { [%clk 0:00:17] } 35. Re3 { [%clk 0:00:04] } 35... Bxe3 { [%clk 0:00:16] } 0-1
# Game 1 without moves:
# [<Game at 0x10e7ff9e0 ('my_name_jeff' vs. 'xxxgrishaxxx', '2025.07.01' at 'https://lichess.org/VsUqVhC2')>]

# %% [markdown]
# ## Next Steps
#
# 1. **Data Collection and Preprocessing**:
#    - Filter games according to the specified criteria (rated games, not bullet/ultra-bullet, etc.)
#    - Group games by username
#    - Exclude users with insufficient number of games
#    - Structure data for analysis
#
# 2. **Feature Engineering**:
#    - Extract relevant features from games (opening choices, play style, etc.)
#    - Create user profiles based on opening preferences
#    - Identify patterns in user opening choices
#
# 3. **Model Development**:
#    - Create a recommendation system that suggests openings based on user profiles
#    - Evaluate model performance
#    - Refine the model based on evaluation results

# %%
# Training data structure

# Note, I have a copilot chat in history about this

# Stuff we don't care about:
# Specific moves in the game
# Maybe time control? Adds a lot of complexity to training data
#

players_stats = {
    "my_username": {
        # Need to decide which TC this is in
        "rating": 1750,
        "black_games": {
            "opening_eco_code_1": {
                "opening_name": "French Defense",
                "results": {
                    "score_percentage_with_opening": 50,
                    "num_games": 74,
                    "num_wins": 15,
                    "num_losses": 25,
                    "num_draws": 7,
                },
            },
        },
        "white_games": {
            "opening_eco_code_1": {
                "opening_name": "French Defense",
                "results": {
                    "score_percentage_with_opening": 50,
                    "num_games": 74,
                    "num_wins": 15,
                    "num_losses": 25,
                    "num_draws": 7,
                },
            },
        },
        "num_games_total": 100,
    },
    "another_username": {
        # ....
    },
}

# %%
# How to extract data from PGN

# Data needed:
# Usernames
# Result
# Opening name and ECO code
# Time control - still need to figure out what we do with this, if any

# Exclude:
# Games shorter than a certain number of moves
# Cheat detected - maybe don't bother with this filter, it's rare and adds complexity
# Bullet games, probably
# Correspondence games maybe?

# Possibly:
# Weight games higher if they're Classical etc? Since players will spend more time on less classical games. Though this adds complexity

# %%
-
# Out:
#   Cell In[49], line 1
#     -
#      ^
# SyntaxError: invalid syntax
